# %% [markdown]
# <img src="../img/uc3m-logo.jpg" alt="UC3M logo" width="200"/>

# %% [markdown]
# # First Homework: Linear and Discrete Models (Topics 1, 2)
# ## BsC in Data Science and Engineering - Optimization and Analytics (2022-2023)
#
# Author: Rodrigo Oliver Coimbra (NIA: 100451788)

# %% [markdown]
# ### 1. Introduction
#
# It can be stated that the role of healthcare is increasingly important in our society as it ages and new treatments are developed by scientists to prevent, cure or mitigate diseases. Sometime during 2019 a novel coronavirus emerged, roughly one hundred years later than the 1918 influeza pandemic, spreading throughout the world and wreacking havoc on communities and testing the ability of the healthcare system to resist such challenges. Hospitals in Spain and all over the world were quick to adapt their processes to this threat and increased their capabilities by expanding the number of beds available and that of the medical staff.
#
# Researchers have been studying bacteria, viruses, fungi, amoebae and animals looking for potential pathogenic beings and vectors so as to monitor them and advise national and international health agencies. Therefore, the possibility of another outbreak cannot be dismissed and healthcare providers should be prepared for such events and have concrete and efficient contingency plans.
#
# An important problem that might be addressed using linear programming tools is the allocation of resources, staff and beds to patients, especially during the course of the acute phase of a pandemic. This is particularly relevant for healthcare providers as they have limited resources on which many lives depend upon.

# %% [markdown]
# ### 2. Model overview (Continuous case)
#
# #### 2.1 General conditions
#
# For this assignment an Intensive Care Unit (ICU) corresponding to a provincial Spanish hospital is used. To this end information was extracted about the number of ICU beds available and the number of intensivists in the University Hospital Complex of León.
#
# The largest number of ICU beds in the University Hospital Complex of León was recorded on February 5, 2021, numbering 80 of them. [<a href="#jcyl-icu-beds">1</a>] This gives us an idea of the increase that would be needed in response to a disease outbreak, the double of the current number of ICU beds (53 as of October 9, 2022) was chosen for the modelling, that is, 106 beds.
#
# According to the website of the University Hospital Complex of León, the medical staff of its Intensive Medicine Unit is comprised by 7 physicians and 5 MIR trainees. [<a href="#jcyl-icu-profile">2</a>]  For this model, 7 physicians plus 3 MIR trainees are considered - plus 7 reinforcements from other hospitals -, therefore amounting to 17 doctors (this information will be used in the Discrete version of the model more precisely). For the continuous version of the model it will be assumed that physicians are working the number of hours that is established by law.
#
# The document *Unidad de cuidados intensivos: Estándares y Recomendaciones* authored by the Spanish Ministry of Health in 2010 establishes the following *assistential levels* (detailed here with some modifications): [<a href="#icu-levels">3</a>]
#
# - Level I
#     - 1 physician per 10 patients (8 am - 6 pm) (on weekdays)
#     - 1 physician per 10 patients (6 pm - 8 am) (on weekdays)
#
# - Level II
#     - 1 physician per 8 patients (8 am - 6 pm) (whole week)
#     - 1 physician per 8 patients (8 am - 6 pm) (on weekdays)
#
# - Level III
#     - 1 physician per 4 patients (8 am - 6 pm) (whole week)
#     - 1 physician per 12 patients (6 pm - 8 am) (whole week)
#
# Each level is adapted to the seriousness and clinical condition of the patients:
#
# | **Level** | **Description**                                                                                                                                    |
# |-----------|----------------------------------------------------------------------------------------------------------------------------------------------------|
# | I         | Patients whose conditions may deteriorate or that came from a higher level of care.                                                                |
# | II         | Patients that require frequent observation/intervention, need machine support, have had an operation recently or came from a higher level of care. |
# | III         | Patients that require breathing support as well as two other vital functions via machine support.                                                  |
#
# This model is similar to that of other European countries and is more or less compatible with the findings of a 2017 research report that suggested the optimal Patient-to-Intensivist ratio being 7.5, being that value the one that minimized hospital mortality. This investigation also indicated that both a reduction and an increase in this ratio lead to higher hospital deaths in a U-shaped form. [<a href="#optimal-PIR">4</a>]
#
# #### 2.2 Specific conditions
#
# Our model will try to minimize the difference between the actual Intensivist-to-Patient ratio and the optimal one that is defined by the Spanish Ministry of Health. This will be achieved by assigning a variable number $x$ of physicians to a given turn for either the Infectious Section and the Non-Infectious Section of the UCI. This model would be of use in the first week of the outbreak where new physicians have not arrived yet.
#
# **Decision variables**
#
# Thus, for a given week:
#
# |                            | Mon      | Tue      | Wed      | Thu      | Fri      | Sat      | Sun      |
# |----------------------------|----------|----------|----------|----------|----------|----------|----------|
# | 8am - 6pm (Level I, infectious)    | $x_{0,0}$ | $x_{0,1}$ | $x_{0,2}$ | $x_{0,3}$ | $x_{0,4}$ | $x_{0,5}$ | $x_{0,6}$ |
# | 8am - 6pm (Level II, infectious)    | $x_{1,0}$ | $x_{1,1}$ | $x_{1,2}$ | $x_{1,3}$ | $x_{1,4}$ | $x_{1,5}$ | $x_{1,6}$ |
# | 8am - 6pm (Level III, infectious)    | $x_{2,0}$ | $x_{2,1}$ | $x_{2,2}$ | $x_{2,3}$ | $x_{2,4}$ | $x_{2,5}$ | $x_{2,6}$ |
# | 6pm - 8am (Level I, infectious)    | $x_{3,0}$ | $x_{3,1}$ | $x_{3,2}$ | $x_{3,3}$ | $x_{3,4}$ | $x_{3,5}$ | $x_{3,6}$ |
# | 6pm - 8am  (Level II, infectious)    | $x_{4,0}$ | $x_{4,1}$ | $x_{4,2}$ | $x_{4,3}$ | $x_{4,4}$ | $x_{4,5}$ | $x_{4,6}$ |
# | 6pm - 8am (Level III, infectious)    | $x_{5,0}$ | $x_{5,1}$ | $x_{5,2}$ | $x_{5,3}$ | $x_{5,4}$ | $x_{5,5}$ | $x_{5,6}$ |
# | 8am - 6pm (Level I, non-infectious)    | $x_{6,0}$ | $x_{6,1}$ | $x_{6,2}$ | $x_{6,3}$ | $x_{6,4}$ | $x_{6,5}$ | $x_{6,6}$ |
# | 8am - 6pm (Level II, non-infectious)    | $x_{7,0}$ | $x_{7,1}$ | $x_{7,2}$ | $x_{7,3}$ | $x_{7,4}$ | $x_{7,5}$ | $x_{7,6}$ |
# | 8am - 6pm (Level III, non-infectious)    | $x_{8,0}$ | $x_{8,1}$ | $x_{8,2}$ | $x_{8,3}$ | $x_{8,4}$ | $x_{8,5}$ | $x_{8,6}$ |
# | 6pm - 8am (Level I, non-infectious)    | $x_{9,0}$ | $x_{9,1}$ | $x_{9,2}$ | $x_{9,3}$ | $x_{9,4}$ | $x_{9,5}$ | $x_{9,6}$ |
# | 6pm - 8am (Level II, non-infectious)    | $x_{10,0}$ | $x_{10,1}$ | $x_{10,2}$ | $x_{10,3}$ | $x_{10,4}$ | $x_{10,5}$ | $x_{10,6}$ |
# | 6pm - 8am (Level III, non-infectious)    | $x_{11,0}$ | $x_{11,1}$ | $x_{11,2}$ | $x_{11,3}$ | $x_{11,4}$ | $x_{11,5}$ | $x_{11,6}$ |
#
# Where $x_{ij}$ represents the number of physicians for a given time, level and type of disease.
#
# According to the definition of each level that was established before the number of doctors $x_{ij}$ for Level I is 0 on weekends and also 0 for Level II on the evening shift during the weekends.
#
# **Constraints**
#
# - The number of doctors in a given time period per day may not exceed half the total number of physicians (so that they cannot have two shifts in one day).
# - The number of doctors $x_{ij}$ for Level I is 0 on weekends.
# - The number of doctors $x_{ij}$ for Level II is 0 on the evening shift during the weekends.
# - There must be at least 1 doctor per 14 patients on Level I.
# - There must be at least 1 doctor per 10 patients on Level II.
# - There must be at least 1 doctor per 6 patients on Level III during the morning shift.
# - There must be at least 1 doctor per 12 patients on Level III during the evening shift.
# - There cannot be a negative number of doctors $x_{ij}$ in any case.
#
# We can further write (notice that they are always doctors available in other levels):
#
# |                            | Mon      | Tue      | Wed      | Thu      | Fri      | Sat      | Sun      |
# |----------------------------|----------|----------|----------|----------|----------|----------|----------|
# | 8am - 6pm (Level I, infectious)    | $x_{0,0}$ | $x_{0,1}$ | $x_{0,2}$ | $x_{0,3}$ | $x_{0,4}$ | $0$ | $0$ |
# | 8am - 6pm (Level II, infectious)    | $x_{1,0}$ | $x_{1,1}$ | $x_{1,2}$ | $x_{1,3}$ | $x_{1,4}$ | $x_{1,5}$ | $x_{1,6}$ |
# | 8am - 6pm (Level III, infectious)    | $x_{2,0}$ | $x_{2,1}$ | $x_{2,2}$ | $x_{2,3}$ | $x_{2,4}$ | $x_{2,5}$ | $x_{2,6}$ |
# | 6pm - 8am (Level I, infectious)    | $x_{3,0}$ | $x_{3,1}$ | $x_{3,2}$ | $x_{3,3}$ | $x_{3,4}$ | $0$ | $0$ |
# | 6pm - 8am  (Level II, infectious)    | $x_{4,0}$ | $x_{4,1}$ | $x_{4,2}$ | $x_{4,3}$ | $x_{4,4}$ | $0$ | $0$ |
# | 6pm - 8am (Level III, infectious)    | $x_{5,0}$ | $x_{5,1}$ | $x_{5,2}$ | $x_{5,3}$ | $x_{5,4}$ | $x_{5,5}$ | $x_{5,6}$ |
# | 8am - 6pm (Level I, non-infectious)    | $x_{6,0}$ | $x_{6,1}$ | $x_{6,2}$ | $x_{6,3}$ | $x_{6,4}$ | $0$ | $0$ |
# | 8am - 6pm (Level II, non-infectious)    | $x_{7,0}$ | $x_{7,1}$ | $x_{7,2}$ | $x_{7,3}$ | $x_{7,4}$ | $x_{7,5}$ | $x_{7,6}$ |
# | 8am - 6pm (Level III, non-infectious)    | $x_{8,0}$ | $x_{8,1}$ | $x_{8,2}$ | $x_{8,3}$ | $x_{8,4}$ | $x_{8,5}$ | $x_{8,6}$ |
# | 6pm - 8am (Level I, non-infectious)    | $x_{9,0}$ | $x_{9,1}$ | $x_{9,2}$ | $x_{9,3}$ | $x_{9,4}$ | $0$ | $0$ |
# | 6pm - 8am (Level II, non-infectious)    | $x_{10,0}$ | $x_{10,1}$ | $x_{10,2}$ | $x_{10,3}$ | $x_{10,4}$ | $0$ | $0$ |
# | 6pm - 8am (Level III, non-infectious)    | $x_{11,0}$ | $x_{11,1}$ | $x_{11,2}$ | $x_{11,3}$ | $x_{11,4}$ | $x_{11,5}$ | $x_{11,6}$ |
#
# In this model the number of patients is estimated by subtracting the incoming patients (with data from the Spanish Ministry of Health) and the outgoing patients. For a given week the prediction is as follows per shift, level and types of disease:
#
# |                                       | Mon      | Tue      | Wed      | Thu      | Fri      | Sat      | Sun      |
# |----------------------------           |----------|----------|----------|----------|----------|----------|----------|
# | 8am - 6pm (Level I, infectious)       | 25       | 22       | 18       | 23       | 30       | 33       | 38       |
# | 8am - 6pm (Level II, infectious)      | 14       | 10       | 12       | 18       | 20       | 24       | 27       |
# | 8am - 6pm (Level III, infectious)     | 5        | 9        | 11       | 11       | 10       | 13       | 16       |
# | 6pm - 8am (Level I, infectious)       | 28       | 24       | 22       | 26       | 25       | 35       | 39       |
# | 6pm - 8am  (Level II, infectious)     | 16       | 11       | 10       | 17       | 16       | 26       | 29       |
# | 6pm - 8am (Level III, infectious)     | 5        | 7        | 10       | 12       | 11       | 15       | 15       |
# | 8am - 6pm (Level I, non-infectious)   | 15       | 8        | 10       | 8        | 7        | 6        | 5        |
# | 8am - 6pm (Level II, non-infectious)  | 9        | 7        | 9        | 7        | 8        | 7        | 6        |
# | 8am - 6pm (Level III, non-infectious) | 10       | 10       | 9        | 10       | 9        | 8        | 8        |
# | 6pm - 8am (Level I, non-infectious)   | 12       | 5        | 8        | 6        | 7        | 5        | 4        |
# | 6pm - 8am (Level II, non-infectious)  | 10       | 9        | 9        | 6        | 8        | 7        | 7        |
# | 6pm - 8am (Level III, non-infectious) | 10       | 6        | 9        | 9        | 9        | 8        | 8        |
#
# Ideal PIR (per Spanish Ministry of Health) with some slight modifications:
#
# |                                       | Optimal PIR      |
# |----------------------------           |----------|
# | 8am - 6pm (Level I, infectious)       | 1/10       |
# | 8am - 6pm (Level II, infectious)      | 1/8      |
# | 8am - 6pm (Level III, infectious)     | 1/4        |
# | 6pm - 8am (Level I, infectious)       | 1/10       |
# | 6pm - 8am  (Level II, infectious)     | 1/8      |
# | 6pm - 8am (Level III, infectious)     | 1/12        |
# | 8am - 6pm (Level I, non-infectious)   | 1/10       |
# | 8am - 6pm (Level II, non-infectious)  | 1/8        |
# | 8am - 6pm (Level III, non-infectious) | 1/4       |
# | 6pm - 8am (Level I, non-infectious)   | 1/10       |
# | 6pm - 8am (Level II, non-infectious)  | 1/8      |
# | 6pm - 8am (Level III, non-infectious) | 1/12       |

# %% [markdown]
# ### 3. General formulation (continous case)

# %% [markdown]
# - **Decision variables**: Quantity of physicians in each turn per level and type of disease, $x_{ij}$ with $0 \leq i \leq 11$ and $0 \leq j \leq 6$. Therefore $M = 12$ and $N = 7$.
#
# - **Objective function**: <span style="color:red">Minimize</span> the difference between the optimal Intensivist-to-Patient ratio set by the Spanish Ministry of Health and the actual one in the first week of the outbreak response.
#
# $$\min_{x_{ij}} \sum_{i=0}^{M-1}{\sum_{j=0}^{N-1}\left(\frac{x_{ij}}{p_{ij}}-r_{i}\right)}$$
#
# - **Constraints**:
#     - The number of doctors in a given time period per day may not exceed half the total number of physicians, so that they cannot have two shifts in one day).
#
#     $$\sum_{i=0}^{5}x_{ij} \leq \frac{G}{2} \qquad \forall \quad 0 \leq j \leq N-1$$
#
#     or alternatively,
#
#     $$\sum_{i=5}^{11}x_{ij} \leq \frac{G}{2} \qquad \forall \quad 0 \leq j \leq N-1$$
#
#     or even better,
#
#     $$\sum_{i=0}^{11}x_{ij} \leq G\qquad \forall \quad 0 \leq j \leq N-1$$
#
#     - The number of doctors $x_{ij}$ for Level I is 0 on weekends.
#     $$x_{0,5} = x_{0,6} = x_{3,5} = x_{3,6} = x_{6,5} = x_{6,6} = x_{9,5} = x_{9,6} = 0$$
#
#     - The number of doctors $x_{ij}$ for Level II is 0 on the evening shift during the weekends.
#     $$x_{4,5} = x_{4,6} = x_{10,5} = x_{10,6} = 0$$
#
#     - There must be at least 1 doctor per 14 patients on Level I (except weekends)
#     $$x_{0,0}, x_{0,1}, \cdots, x_{0,4} \quad \frac{x_{0j}}{p_{0j}} \geq \frac{1}{14}$$
#     $$x_{3,0}, x_{3,1}, \cdots, x_{3,4} \quad \frac{x_{3j}}{p_{3j}} \geq \frac{1}{14}$$
#     $$x_{6,0}, x_{6,1}, \cdots, x_{6,4} \quad \frac{x_{6j}}{p_{6j}} \geq \frac{1}{14}$$
#     $$x_{9,0}, x_{9,1}, \cdots, x_{9,4} \quad \frac{x_{9j}}{p_{9j}} \geq \frac{1}{14}$$
#
#     - There must be at least 1 doctor per 10 patients on Level II (except weekend evenings)
#     $$x_{1,0}, x_{1,1}, \cdots, x_{1,6} \quad \frac{x_{1j}}{p_{1j}} \geq \frac{1}{10}$$
#     $$x_{4,0}, x_{4,1}, \cdots, x_{4,4} \quad \frac{x_{4j}}{p_{4j}} \geq \frac{1}{10}$$
#     $$x_{7,0}, x_{7,1}, \cdots, x_{7,6} \quad \frac{x_{7j}}{p_{7j}} \geq \frac{1}{10}$$
#     $$x_{10,0}, x_{10,1}, \cdots, x_{10,4} \quad \frac{x_{10j}}{p_{10j}} \geq \frac{1}{10}$$
#
#
#     - There must be at least 1 doctor per 6 patients on Level III during the morning shift.
#     $$x_{2,0}, x_{2,1}, \cdots, x_{2,6} \quad \frac{x_{2j}}{p_{2j}} \geq \frac{1}{6}$$
#     $$x_{8,0}, x_{8,1}, \cdots, x_{8,6} \quad \frac{x_{8j}}{p_{8j}} \geq \frac{1}{6}$$
#
#     - There must be at least 1 doctor per 12 patients on Level III during the evening shift.
#     $$x_{5,0}, x_{5,1}, \cdots, x_{5,6} \quad \frac{x_{5j}}{p_{5j}} \geq \frac{1}{12}$$
#     $$x_{11,0}, x_{11,1}, \cdots, x_{11,6} \quad \frac{x_{11j}}{p_{11j}} \geq \frac{1}{12}$$
#
#
#     - There can never be a negative number of doctors $x_{ij}$.
#     $$x_{ij} \geq 0 \qquad \forall \quad 0 \leq i \leq M-1, \quad 0 \leq j \leq N-1$$

# %% [markdown]
# ### 4. Implementation (continuous case)

# %%
# We import the libraries that are needed
# for solving linear programming problems
import pyomo.environ as pyo
from pyomo.opt import SolverFactory

# For performance analysis purposes
from time import process_time

# For saving the results returned by the solver
from pandas import Series, DataFrame

# For better code readability and maintanability
from typing import Final

# Define the constants
NUMBER_OF_INTENSIVISTS: Final = 17
WEEK: Final = ['Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun']
WEEKDAYS: Final = WEEK[:5]
WEEKEND: Final = WEEK[-2:]
SHIFTS: Final = [
    'M1i', 'M2i', 'M3i',
    'E1i', 'E2i', 'E3i', 
    'M1n', 'M2n', 'M3n',
    'E1n', 'E2n', 'E3n'
    ]

# %% [markdown]
# #### 4.0 Problem data definition: sets and parameters

# %%
# We define the continuous model
continuous_model = pyo.ConcreteModel('Continuous model')

# We create the labels of the 1st dimension of the continuous model
# that correspondes to the rows of our previously seen matrix
i_labels = SHIFTS

# We check that the the length of the 1st dimension
# is equal to 12
assert len(i_labels) == 12

# We create the labels of the 2nd dimension of the continuous model
# that corresponds to the columns of our previously seen matrix
j_labels = WEEK

# We check the length of the 2nd dimension
# to be equal to 7
assert len(j_labels) == 7

# We initialize the model dimensions with the labels
# that were defined above
continuous_model.i = pyo.Set(initialize = i_labels, doc = "scenarios")
continuous_model.j = pyo.Set(initialize = j_labels, doc = "days of the week")

patient_forecast = {

    # In-Python used notation:
    # M <- morning shift; E <- evening shift
    # 1, 2, 3 <- Assistance Level
    # i <- infectious; n <- non-infectious

    ('M1i', 'Mon'): 25,
    ('M1i', 'Tue'): 22,
    ('M1i', 'Wed'): 18,
    ('M1i', 'Thu'): 23,
    ('M1i', 'Fri'): 30,
    ('M1i', 'Sat'): 33,
    ('M1i', 'Sun'): 38,

    ('M2i', 'Mon'): 14,
    ('M2i', 'Tue'): 10,
    ('M2i', 'Wed'): 12,
    ('M2i', 'Thu'): 18,
    ('M2i', 'Fri'): 20,
    ('M2i', 'Sat'): 24,
    ('M2i', 'Sun'): 27,

    ('M3i', 'Mon'): 5,
    ('M3i', 'Tue'): 9,
    ('M3i', 'Wed'): 11,
    ('M3i', 'Thu'): 11,
    ('M3i', 'Fri'): 10,
    ('M3i', 'Sat'): 13,
    ('M3i', 'Sun'): 16,

    ('E1i', 'Mon'): 28,
    ('E1i', 'Tue'): 24,
    ('E1i', 'Wed'): 22,
    ('E1i', 'Thu'): 26,
    ('E1i', 'Fri'): 25,
    ('E1i', 'Sat'): 35,
    ('E1i', 'Sun'): 39,

    ('E2i', 'Mon'): 16,
    ('E2i', 'Tue'): 11,
    ('E2i', 'Wed'): 10,
    ('E2i', 'Thu'): 17,
    ('E2i', 'Fri'): 16,
    ('E2i', 'Sat'): 26,
    ('E2i', 'Sun'): 29,

    ('E3i', 'Mon'): 5,
    ('E3i', 'Tue'): 7,
    ('E3i', 'Wed'): 10,
    ('E3i', 'Thu'): 12,
    ('E3i', 'Fri'): 11,
    ('E3i', 'Sat'): 15,
    ('E3i', 'Sun'): 15,

    ('M1n', 'Mon'): 15,
    ('M1n', 'Tue'): 8,
    ('M1n', 'Wed'): 10,
    ('M1n', 'Thu'): 8,
    ('M1n', 'Fri'): 7,
    ('M1n', 'Sat'): 6,
    ('M1n', 'Sun'): 5,

    ('M2n', 'Mon'): 9,
    ('M2n', 'Tue'): 7,
    ('M2n', 'Wed'): 9,
    ('M2n', 'Thu'): 7,
    ('M2n', 'Fri'): 8,
    ('M2n', 'Sat'): 7,
    ('M2n', 'Sun'): 6,

    ('M3n', 'Mon'): 10,
    ('M3n', 'Tue'): 10,
    ('M3n', 'Wed'): 9,
    ('M3n', 'Thu'): 10,
    ('M3n', 'Fri'): 9,
    ('M3n', 'Sat'): 8,
    ('M3n', 'Sun'): 8,

    ('E1n', 'Mon'): 12,
    ('E1n', 'Tue'): 5,
    ('E1n', 'Wed'): 8,
    ('E1n', 'Thu'): 6,
    ('E1n', 'Fri'): 7,
    ('E1n', 'Sat'): 5,
    ('E1n', 'Sun'): 4,

    ('E2n', 'Mon'): 10,
    ('E2n', 'Tue'): 9,
    ('E2n', 'Wed'): 9,
    ('E2n', 'Thu'): 6,
    ('E2n', 'Fri'): 8,
    ('E2n', 'Sat'): 7,
    ('E2n', 'Sun'): 7,

    ('E3n', 'Mon'): 10,
    ('E3n', 'Tue'): 6,
    ('E3n', 'Wed'): 9,
    ('E3n', 'Thu'): 9,
    ('E3n', 'Fri'): 9,
    ('E3n', 'Sat'): 8,
    ('E3n', 'Sun'): 8
    
}

# We check the length of matrix
# to be equal to 84 (12 x 7)
assert len(patient_forecast.items()) == 84

# We define the forescated number of patients per scenario and
# days of the week into the model. This information is
# crucial in the solution to the problem
continuous_model.patients = pyo.Param(continuous_model.i, continuous_model.j,
    initialize = patient_forecast, doc = "Forescasted patients per scenario and day of the week")

# Print the basic parts of the continuous model
continuous_model.pprint()
# Out:
# 3 Set Declarations
#     i : scenarios
#         Size=1, Index=None, Ordered=Insertion
#         Key  : Dimen : Domain : Size : Members
#         None :     1 :    Any :   12 : {'M1i', 'M2i', 'M3i', 'E1i', 'E2i', 'E3i', 'M1n', 'M2n', 'M3n', 'E1n', 'E2n', 'E3n'}
#     j : days of the week
#         Size=1, Index=None, Ordered=Insertion
#         Key  : Dimen : Domain : Size : Members
#         None :     1 :    Any :    7 : {'Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun'}
#     patients_index : Size=1, Index=None, Ordered=True
#         Key  : Dimen : Domain : Size : Members
#         None :     2 :    i*j :   84 : {('M1i', 'Mon'), ('M1i', 'Tue'), ('M1i', 'Wed'), ('M1i', 'Thu'), ('M1i', 'Fri'), ('M1i', 'Sat'), ('M1i', 'Sun'), ('M2i', 'Mon'), ('M2i', 'Tue'), ('M2i', 'Wed'), ('M2i', 'Thu'), ('M2i', 'Fri'), ('M2i', 'Sat'), ('M2i', 'Sun'), ('M3i', 'Mon'), ('M3i', 'Tue'), ('M3i', 'Wed'), ('M3i', 'Thu'), ('M3i', 'Fri'), ('M3i', 'Sat'), ('M3i', 'Sun'), ('E1i', 'Mon'), ('E1i', 'Tue'), ('E1i', 'Wed'), ('E1i', 'Thu'), ('E1i', 'Fri'), ('E1i', 'Sat'), ('E1i', 'Sun'), ('E2i', 'Mon'), ('E2i', 'Tue'), ('E2i', 'Wed'), ('E2i', 'Thu'), ('E2i', 'Fri'), ('E2i', 'Sat'), ('E2i', 'Sun'), ('E3i', 'Mon'), ('E3i', 'Tue'), ('E3i', 'Wed'), ('E3i', 'Thu'), ('E3i', 'Fri'), ('E3i', 'Sat'), ('E3i', 'Sun'), ('M1n', 'Mon'), ('M1n', 'Tue'), ('M1n', 'Wed'), ('M1n', 'Thu'), ('M1n', 'Fri'), ('M1n', 'Sat'), ('M1n', 'Sun'), ('M2n', 'Mon'), ('M2n', 'Tue'), ('M2n', 'Wed'), ('M2n', 'Thu'), ('M2n', 'Fri'), ('M2n', 'Sat'), ('M2n', 'Sun'), ('M3n', 'Mon'), ('M3n', 'Tue'), ('M3n', 'Wed'), ('M3n', 'Thu'), ('M3n', 'Fri'), ('M3n', 'Sat'), ('M3n', 'Sun'), ('E1n', 'Mon'), ('E1n', 'Tue'), ('E1n', 'Wed'), ('E1n', 'Thu'), ('E1n', 'Fri'), ('E1n', 'Sat'), ('E1n', 'Sun'), ('E2n', 'Mon'), ('E2n', 'Tue'), ('E2n', 'Wed'), ('E2n', 'Thu'), ('E2n', 'Fri'), ('E2n', 'Sat'), ('E2n', 'Sun'), ('E3n', 'Mon'), ('E3n', 'Tue'), ('E3n', 'Wed'), ('E3n', 'Thu'), ('E3n', 'Fri'), ('E3n', 'Sat'), ('E3n', 'Sun')}
#
# 1 Param Declarations
#     patients : Forescasted patients per scenario and day of the week
#         Size=84, Index=patients_index, Domain=Any, Default=None, Mutable=False
#         Key            : Value
#         ('E1i', 'Fri') :    25
#         ('E1i', 'Mon') :    28
#         ('E1i', 'Sat') :    35
#         ('E1i', 'Sun') :    39
#         ('E1i', 'Thu') :    26
#         ('E1i', 'Tue') :    24
#         ('E1i', 'Wed') :    22
#         ('E1n', 'Fri') :     7
#         ('E1n', 'Mon') :    12
#         ('E1n', 'Sat') :     5
#         ('E1n', 'Sun') :     4
#         ('E1n', 'Thu') :     6
#         ('E1n', 'Tue') :     5
#         ('E1n', 'Wed') :     8
#         ('E2i', 'Fri') :    16
#         ('E2i', 'Mon') :    16
#         ('E2i', 'Sat') :    26
#         ('E2i', 'Sun') :    29
#         ('E2i', 'Thu') :    17
#         ('E2i', 'Tue') :    11
#         ('E2i', 'Wed') :    10
#         ('E2n', 'Fri') :     8
#         ('E2n', 'Mon') :    10
#         ('E2n', 'Sat') :     7
#         ('E2n', 'Sun') :     7
#         ('E2n', 'Thu') :     6
#         ('E2n', 'Tue') :     9
#         ('E2n', 'Wed') :     9
#         ('E3i', 'Fri') :    11
#         ('E3i', 'Mon') :     5
#         ('E3i', 'Sat') :    15
#         ('E3i', 'Sun') :    15
#         ('E3i', 'Thu') :    12
#         ('E3i', 'Tue') :     7
#         ('E3i', 'Wed') :    10
#         ('E3n', 'Fri') :     9
#         ('E3n', 'Mon') :    10
#         ('E3n', 'Sat') :     8
#         ('E3n', 'Sun') :     8
#         ('E3n', 'Thu') :     9
#         ('E3n', 'Tue') :     6
#         ('E3n', 'Wed') :     9
#         ('M1i', 'Fri') :    30
#         ('M1i', 'Mon') :    25
#         ('M1i', 'Sat') :    33
#         ('M1i', 'Sun') :    38
#         ('M1i', 'Thu') :    23
#         ('M1i', 'Tue') :    22
#         ('M1i', 'Wed') :    18
#         ('M1n', 'Fri') :     7
#         ('M1n', 'Mon') :    15
#         ('M1n', 'Sat') :     6
#         ('M1n', 'Sun') :     5
#         ('M1n', 'Thu') :     8
#         ('M1n', 'Tue') :     8
#         ('M1n', 'Wed') :    10
#         ('M2i', 'Fri') :    20
#         ('M2i', 'Mon') :    14
#         ('M2i', 'Sat') :    24
#         ('M2i', 'Sun') :    27
#         ('M2i', 'Thu') :    18
#         ('M2i', 'Tue') :    10
#         ('M2i', 'Wed') :    12
#         ('M2n', 'Fri') :     8
#         ('M2n', 'Mon') :     9
#         ('M2n', 'Sat') :     7
#         ('M2n', 'Sun') :     6
#         ('M2n', 'Thu') :     7
#         ('M2n', 'Tue') :     7
#         ('M2n', 'Wed') :     9
#         ('M3i', 'Fri') :    10
#         ('M3i', 'Mon') :     5
#         ('M3i', 'Sat') :    13
#         ('M3i', 'Sun') :    16
#         ('M3i', 'Thu') :    11
#         ('M3i', 'Tue') :     9
#         ('M3i', 'Wed') :    11
#         ('M3n', 'Fri') :     9
#         ('M3n', 'Mon') :    10
#         ('M3n', 'Sat') :     8
#         ('M3n', 'Sun') :     8
#         ('M3n', 'Thu') :    10
#         ('M3n', 'Tue') :    10
#         ('M3n', 'Wed') :     9
#
# 4 Declarations: i j patients_index patients

# %% [markdown]
# #### 4.1 Define the variables

# %%
# We define variables x(i,j)
# that represent the number of intensivists
# per scenario, per day of the week
continuous_model.x = pyo.Var(continuous_model.i, continuous_model.j,
    doc = "Number of intensivists",
    within = pyo.NonNegativeReals)

print(continuous_model.x.display())
# Out:
# x : Number of intensivists
#     Size=84, Index=x_index
#     Key            : Lower : Value : Upper : Fixed : Stale : Domain
#     ('E1i', 'Fri') :     0 :  None :  None : False :  True : NonNegativeReals
#     ('E1i', 'Mon') :     0 :  None :  None : False :  True : NonNegativeReals
#     ('E1i', 'Sat') :     0 :  None :  None : False :  True : NonNegativeReals
#     ('E1i', 'Sun') :     0 :  None :  None : False :  True : NonNegativeReals
#     ('E1i', 'Thu') :     0 :  None :  None : False :  True : NonNegativeReals
#     ('E1i', 'Tue') :     0 :  None :  None : False :  True : NonNegativeReals
#     ('E1i', 'Wed') :     0 :  None :  None : False :  True : NonNegativeReals
#     ('E1n', 'Fri') :     0 :  None :  None : False :  True : NonNegativeReals
#     ('E1n', 'Mon') :     0 :  None :  None : False :  True : NonNegativeReals
#     ('E1n', 'Sat') :     0 :  None :  None : False :  True : NonNegativeReals
#     ('E1n', 'Sun') :     0 :  None :  None : False :  True : NonNegativeReals
#     ('E1n', 'Thu') :     0 :  None :  None : False :  True : NonNegativeReals
#     ('E1n', 'Tue') :     0 :  None :  None : False :  True : NonNegativeReals
#     ('E1n', 'Wed') :     0 :  None :  None : False :  True : NonNegativeReals
#     ('E2i', 'Fri') :     0 :  None :  None : False :  True : NonNegativeReals
#     ('E2i', 'Mon') :     0 :  None :  None : False :  True : NonNegativeReals
#     ('E2i', 'Sat') :     0 :  None :  None : False :  True : NonNegativeReals
#     ('E2i', 'Sun') :     0 :  None :  None : False :  True : NonNegativeReals
#     ('E2i', 'Thu') :     0 :  None :  None : False :  True : NonNegativeReals
#     ('E2i', 'Tue') :     0 :  None :  None : False :  True : NonNegativeReals
#     ('E2i', 'Wed') :     0 :  None :  None : False :  True : NonNegativeReals
#     ('E2n', 'Fri') :     0 :  None :  None : False :  True : NonNegativeReals
#     ('E2n', 'Mon') :     0 :  None :  None : False :  True : NonNegativeReals
#     ('E2n', 'Sat') :     0 :  None :  None : False :  True : NonNegativeReals
#     ('E2n', 'Sun') :     0 :  None :  None : False :  True : NonNegativeReals
#     ('E2n', 'Thu') :     0 :  None :  None : False :  True : NonNegativeReals
#     ('E2n', 'Tue') :     0 :  None :  None : False :  True : NonNegativeReals
#     ('E2n', 'Wed') :     0 :  None :  None : False :  True : NonNegativeReals
#     ('E3i', 'Fri') :     0 :  None :  None : False :  True : NonNegativeReals
#     ('E3i', 'Mon') :     0 :  None :  None : False :  True : NonNegativeReals
#     ('E3i', 'Sat') :     0 :  None :  None : False :  True : NonNegativeReals
#     ('E3i', 'Sun') :     0 :  None :  None : False :  True : NonNegativeReals
#     ('E3i', 'Thu') :     0 :  None :  None : False :  True : NonNegativeReals
#     ('E3i', 'Tue') :     0 :  None :  None : False :  True : NonNegativeReals
#     ('E3i', 'Wed') :     0 :  None :  None : False :  True : NonNegativeReals
#     ('E3n', 'Fri') :     0 :  None :  None : False :  True : NonNegativeReals
#     ('E3n', 'Mon') :     0 :  None :  None : False :  True : NonNegativeReals
#     ('E3n', 'Sat') :     0 :  None :  None : False :  True : NonNegativeReals
#     ('E3n', 'Sun') :     0 :  None :  None : False :  True : NonNegativeReals
#     ('E3n', 'Thu') :     0 :  None :  None : False :  True : NonNegativeReals
#     ('E3n', 'Tue') :     0 :  None :  None : False :  True : NonNegativeReals
#     ('E3n', 'Wed') :     0 :  None :  None : False :  True : NonNegativeReals
#     ('M1i', 'Fri') :     0 :  None :  None : False :  True : NonNegativeReals
#     ('M1i', 'Mon') :     0 :  None :  None : False :  True : NonNegativeReals
#     ('M1i', 'Sat') :     0 :  None :  None : False :  True : NonNegativeReals
#     ('M1i', 'Sun') :     0 :  None :  None : False :  True : NonNegativeReals
#     ('M1i', 'Thu') :     0 :  None :  None : False :  True : NonNegativeReals
#     ('M1i', 'Tue') :     0 :  None :  None : False :  True : NonNegativeReals
#     ('M1i', 'Wed') :     0 :  None :  None : False :  True : NonNegativeReals
#     ('M1n', 'Fri') :     0 :  None :  None : False :  True : NonNegativeReals
#     ('M1n', 'Mon') :     0 :  None :  None : False :  True : NonNegativeReals
#     ('M1n', 'Sat') :     0 :  None :  None : False :  True : NonNegativeReals
#     ('M1n', 'Sun') :     0 :  None :  None : False :  True : NonNegativeReals
#     ('M1n', 'Thu') :     0 :  None :  None : False :  True : NonNegativeReals
#     ('M1n', 'Tue') :     0 :  None :  None : False :  True : NonNegativeReals
#     ('M1n', 'Wed') :     0 :  None :  None : False :  True : NonNegativeReals
#     ('M2i', 'Fri') :     0 :  None :  None : False :  True : NonNegativeReals
#     ('M2i', 'Mon') :     0 :  None :  None : False :  True : NonNegativeReals
#     ('M2i', 'Sat') :     0 :  None :  None : False :  True : NonNegativeReals
#     ('M2i', 'Sun') :     0 :  None :  None : False :  True : NonNegativeReals
#     ('M2i', 'Thu') :     0 :  None :  None : False :  True : NonNegativeReals
#     ('M2i', 'Tue') :     0 :  None :  None : False :  True : NonNegativeReals
#     ('M2i', 'Wed') :     0 :  None :  None : False :  True : NonNegativeReals
#     ('M2n', 'Fri') :     0 :  None :  None : False :  True : NonNegativeReals
#     ('M2n', 'Mon') :     0 :  None :  None : False :  True : NonNegativeReals
#     ('M2n', 'Sat') :     0 :  None :  None : False :  True : NonNegativeReals
#     ('M2n', 'Sun') :     0 :  None :  None : False :  True : NonNegativeReals
#     ('M2n', 'Thu') :     0 :  None :  None : False :  True : NonNegativeReals
#     ('M2n', 'Tue') :     0 :  None :  None : False :  True : NonNegativeReals
#     ('M2n', 'Wed') :     0 :  None :  None : False :  True : NonNegativeReals
#     ('M3i', 'Fri') :     0 :  None :  None : False :  True : NonNegativeReals
#     ('M3i', 'Mon') :     0 :  None :  None : False :  True : NonNegativeReals
#     ('M3i', 'Sat') :     0 :  None :  None : False :  True : NonNegativeReals
#     ('M3i', 'Sun') :     0 :  None :  None : False :  True : NonNegativeReals
#     ('M3i', 'Thu') :     0 :  None :  None : False :  True : NonNegativeReals
#     ('M3i', 'Tue') :     0 :  None :  None : False :  True : NonNegativeReals
#     ('M3i', 'Wed') :     0 :  None :  None : False :  True : NonNegativeReals
#     ('M3n', 'Fri') :     0 :  None :  None : False :  True : NonNegativeReals
#     ('M3n', 'Mon') :     0 :  None :  None : False :  True : NonNegativeReals
#     ('M3n', 'Sat') :     0 :  None :  None : False :  True : NonNegativeReals
#     ('M3n', 'Sun') :     0 :  None :  None : False :  True : NonNegativeReals
#     ('M3n', 'Thu') :     0 :  None :  None : False :  True : NonNegativeReals
#     ('M3n', 'Tue') :     0 :  None :  None : False :  True : NonNegativeReals
#     ('M3n', 'Wed') :     0 :  None :  None : False :  True : NonNegativeReals
# None

# %% [markdown]
# #### 4.2 Define the objective function

# %%
# We define the optimal Intensivist to Patient ratios
# per scenario in accordance with the recommendations
# and instructions of the Spanish Ministry of Health
optimal_ratios = [
    1/10, 1/8, 1/4,
    1/10, 1/8, 1/12,
    1/10, 1/8, 1/4,
    1/10, 1/8, 1/12
    ]

# We check the optimal_ratios length
# to be 12 (one per scenario)
assert len(optimal_ratios) == 12

# %%
# We define the objective function to be used
def c_objective_rule(c_model: pyo.ConcreteModel) -> float:
    return sum([((c_model.x[i,j]/c_model.patients[i,j])-optimal_ratios[count]) for count, i in enumerate(c_model.i) for j in c_model.j])

# %%
# We instantiate the objective function for the model which is passed as a rule
# although Pyomo minimizes by default, we still explicitly specify this
continuous_model.objective = pyo.Objective(
                                            rule = c_objective_rule,
                                            sense = pyo.minimize,
                                             doc = "Real-to-Optimal Intensivist-to-Patient ratio"
                                             )

# %% [markdown]
# #### 4.3 Define the constraints

# %%
# Function that establishes the constraint by which the solution to the number of doctors
# cannot be larger than the number of available medical staff
def c_MaxStaffPerDay(c_model: pyo.ConcreteModel, j: str) -> bool:
    return sum(c_model.x[i,j] for i in c_model.i) <= NUMBER_OF_INTENSIVISTS

# %%
# This constraint is now added to the model
continuous_model.maxStaffPerDay = pyo.Constraint(
    continuous_model.j,
    rule = c_MaxStaffPerDay,
    doc = "Maximum number of doctors per day")

# %%
# Function that establishes that the presence of physicians
# is not prescribed for Level I during the weekend
def c_WeekendRulesFirstLevel(c_model: pyo.ConcreteModel, constraintList: pyo.ConstraintList) -> None:
    row_list = ['M1i', 'E1i', 'M1n', 'E1n']
    for i in row_list:
        for j in WEEKEND:
            constraintList.add(expr = c_model.x[i,j] == 0)
    
    assert len(constraintList) == 8
    constraintList.pprint()
    
    return

# Function that establishes that the presence of physicians
# is not prescribed for Level II during the weekend
# during the evening shift
def c_WeekendRulesSecondLevel(c_model: pyo.ConcreteModel, constraintList: pyo.ConstraintList) -> None:
    row_list = ['E2i', 'E2n']
    for i in row_list:
        for j in WEEKEND:
            constraintList.add(expr = c_model.x[i,j] == 0)

    assert len(constraintList) == 4
    constraintList.pprint()

    return

# %%
"""
continuous_model.weekendRules = pyo.Constraint(
    rule = c_WeekendRules,
    doc = "Medical staff weekend restrictions"
)
"""

# The medical staff constraints for Level I
# during the weekend are added to the model
continuous_model.weekendrules_firstlevel = pyo.ConstraintList()
c_WeekendRulesFirstLevel(continuous_model, continuous_model.weekendrules_firstlevel)

# The medical staff constraints for Level I
# during the weekend in the evening shift
# are added to the model
continuous_model.weekendrules_secondlevel = pyo.ConstraintList()
c_WeekendRulesSecondLevel(continuous_model, continuous_model.weekendrules_secondlevel)
# Out:
# weekendrules_firstlevel : Size=8, Index=weekendrules_firstlevel_index, Active=True
#     Key : Lower : Body       : Upper : Active
#       1 :   0.0 : x[M1i,Sat] :   0.0 :   True
#       2 :   0.0 : x[M1i,Sun] :   0.0 :   True
#       3 :   0.0 : x[E1i,Sat] :   0.0 :   True
#       4 :   0.0 : x[E1i,Sun] :   0.0 :   True
#       5 :   0.0 : x[M1n,Sat] :   0.0 :   True
#       6 :   0.0 : x[M1n,Sun] :   0.0 :   True
#       7 :   0.0 : x[E1n,Sat] :   0.0 :   True
#       8 :   0.0 : x[E1n,Sun] :   0.0 :   True
# weekendrules_secondlevel : Size=4, Index=weekendrules_secondlevel_index, Active=True
#     Key : Lower : Body       : Upper : Active
#       1 :   0.0 : x[E2i,Sat] :   0.0 :   True
#       2 :   0.0 : x[E2i,Sun] :   0.0 :   True
#       3 :   0.0 : x[E2n,Sat] :   0.0 :   True
#       4 :   0.0 : x[E2n,Sun] :   0.0 :   True

# %%
# Function that implements the minimal Intensivist-to-Patients ratio that
# is minimally admissible taking into account healthcare standards
# for Level I (which only requires physicians during weekdays)
def c_MinProportionFirstLevel(c_model: pyo.ConcreteModel, constraintList: pyo.ConstraintList) -> None:
    row_list = ['M1i', 'E1i', 'M1n', 'E1n']
    for i in row_list:
        for j in WEEKDAYS:
            constraintList.add(expr = c_model.x[i,j]/c_model.patients[i,j] >= 1/14)

    assert len(constraintList) == 20
    constraintList.pprint()
    
    return

# %%
# Function that implements the minimal Intensivist-to-Patients ratio that
# is minimally admissible taking into account healthcare standards
# for Level II (which only requires physicians all week for the
# morning shift, but not for the evening one)
def c_MinProportionSecondLevel(c_model: pyo.ConcreteModel, constraintList: pyo.ConstraintList) -> None:

    # MORNING SHIFT
    row_list_morning = ['M2i', 'M2n']
    for i in row_list_morning:
        for j in WEEK:
            constraintList.add(expr = c_model.x[i,j]/c_model.patients[i,j] >= 1/10)

    # EVENING SHIFT
    row_list_evening = ['E2i', 'E2n']
    for i in row_list_evening:
        for j in WEEKDAYS:
            constraintList.add(expr = c_model.x[i,j]/c_model.patients[i,j] >= 1/10)
    
    assert len(constraintList) == 24
    constraintList.pprint()

    return

# %%
# Function that implements the minimal Intensivist-to-Patients ratio that
# is minimally admissible taking into account healthcare standards
# for Level III (which requires physicians all week but at
# different ratios, in the morning shift at min. 1/6 and
# at the evening one at min. 1/12)
def c_MinProportionThirdLevel(c_model: pyo.ConcreteModel, constraintList: pyo.ConstraintList) -> None:

    # MORNING SHIFT
    row_list_morning = ['M3i', 'M3n']
    for i in row_list_morning:
        for j in WEEK:
            constraintList.add(expr = c_model.x[i,j]/c_model.patients[i,j] >= 1/6)

    # EVENING SHIFT
    row_list_evening = ['E3i', 'E3n']
    for i in row_list_evening:
        for j in WEEK:
            constraintList.add(expr = c_model.x[i,j]/c_model.patients[i,j] >= 1/12)

    assert len(constraintList) == 28
    constraintList.pprint()

    return

# %%
# The minimal Intensivist-to-Patient constraints for 
# Level I are added to the model
continuous_model.minproportions_firstlevel = pyo.ConstraintList()
c_MinProportionFirstLevel(continuous_model, continuous_model.minproportions_firstlevel)
# Out:
# minproportions_firstlevel : Size=20, Index=minproportions_firstlevel_index, Active=True
#     Key : Lower               : Body                            : Upper : Active
#       1 : 0.07142857142857142 :                 0.04*x[M1i,Mon] :  +Inf :   True
#       2 : 0.07142857142857142 : 0.045454545454545456*x[M1i,Tue] :  +Inf :   True
#       3 : 0.07142857142857142 :  0.05555555555555555*x[M1i,Wed] :  +Inf :   True
#       4 : 0.07142857142857142 : 0.043478260869565216*x[M1i,Thu] :  +Inf :   True
#       5 : 0.07142857142857142 :  0.03333333333333333*x[M1i,Fri] :  +Inf :   True
#       6 : 0.07142857142857142 :  0.03571428571428571*x[E1i,Mon] :  +Inf :   True
#       7 : 0.07142857142857142 : 0.041666666666666664*x[E1i,Tue] :  +Inf :   True
#       8 : 0.07142857142857142 : 0.045454545454545456*x[E1i,Wed] :  +Inf :   True
#       9 : 0.07142857142857142 : 0.038461538461538464*x[E1i,Thu] :  +Inf :   True
#      10 : 0.07142857142857142 :                 0.04*x[E1i,Fri] :  +Inf :   True
#      11 : 0.07142857142857142 :  0.06666666666666667*x[M1n,Mon] :  +Inf :   True
#      12 : 0.07142857142857142 :                0.125*x[M1n,Tue] :  +Inf :   True
#      13 : 0.07142857142857142 :                  0.1*x[M1n,Wed] :  +Inf :   True
#      14 : 0.07142857142857142 :                0.125*x[M1n,Thu] :  +Inf :   True
#      15 : 0.07142857142857142 :  0.14285714285714285*x[M1n,Fri] :  +Inf :   True
#      16 : 0.07142857142857142 :  0.08333333333333333*x[E1n,Mon] :  +Inf :   True
#      17 : 0.07142857142857142 :                  0.2*x[E1n,Tue] :  +Inf :   True
#      18 : 0.07142857142857142 :                0.125*x[E1n,Wed] :  +Inf :   True
#      19 : 0.07142857142857142 :  0.16666666666666666*x[E1n,Thu] :  +Inf :   True
#      20 : 0.07142857142857142 :  0.14285714285714285*x[E1n,Fri] :  +Inf :   True

# %%
# The minimal Intensivist-to-Patient constraints for 
# Level II are added to the model
continuous_model.minproportions_secondlevel = pyo.ConstraintList()
c_MinProportionSecondLevel(continuous_model, continuous_model.minproportions_secondlevel)
# Out:
# minproportions_secondlevel : Size=24, Index=minproportions_secondlevel_index, Active=True
#     Key : Lower : Body                            : Upper : Active
#       1 :   0.1 :  0.07142857142857142*x[M2i,Mon] :  +Inf :   True
#       2 :   0.1 :                  0.1*x[M2i,Tue] :  +Inf :   True
#       3 :   0.1 :  0.08333333333333333*x[M2i,Wed] :  +Inf :   True
#       4 :   0.1 :  0.05555555555555555*x[M2i,Thu] :  +Inf :   True
#       5 :   0.1 :                 0.05*x[M2i,Fri] :  +Inf :   True
#       6 :   0.1 : 0.041666666666666664*x[M2i,Sat] :  +Inf :   True
#       7 :   0.1 : 0.037037037037037035*x[M2i,Sun] :  +Inf :   True
#       8 :   0.1 :   0.1111111111111111*x[M2n,Mon] :  +Inf :   True
#       9 :   0.1 :  0.14285714285714285*x[M2n,Tue] :  +Inf :   True
#      10 :   0.1 :   0.1111111111111111*x[M2n,Wed] :  +Inf :   True
#      11 :   0.1 :  0.14285714285714285*x[M2n,Thu] :  +Inf :   True
#      12 :   0.1 :                0.125*x[M2n,Fri] :  +Inf :   True
#      13 :   0.1 :  0.14285714285714285*x[M2n,Sat] :  +Inf :   True
#      14 :   0.1 :  0.16666666666666666*x[M2n,Sun] :  +Inf :   True
#      15 :   0.1 :               0.0625*x[E2i,Mon] :  +Inf :   True
#      16 :   0.1 :  0.09090909090909091*x[E2i,Tue] :  +Inf :   True
#      17 :   0.1 :                  0.1*x[E2i,Wed] :  +Inf :   True
#      18 :   0.1 : 0.058823529411764705*x[E2i,Thu] :  +Inf :   True
#      19 :   0.1 :               0.0625*x[E2i,Fri] :  +Inf :   True
#      20 :   0.1 :                  0.1*x[E2n,Mon] :  +Inf :   True
#      21 :   0.1 :   0.1111111111111111*x[E2n,Tue] :  +Inf :   True
#      22 :   0.1 :   0.1111111111111111*x[E2n,Wed] :  +Inf :   True
#      23 :   0.1 :  0.16666666666666666*x[E2n,Thu] :  +Inf :   True
#      24 :   0.1 :                0.125*x[E2n,Fri] :  +Inf :   True

# %%
# The minimal Intensivist-to-Patient constraints for 
# Level III are added to the model
continuous_model.minproportions_thirdlevel = pyo.ConstraintList()
c_MinProportionThirdLevel(continuous_model, continuous_model.minproportions_thirdlevel)
# Out:
# minproportions_thirdlevel : Size=28, Index=minproportions_thirdlevel_index, Active=True
#     Key : Lower               : Body                           : Upper : Active
#       1 : 0.16666666666666666 :                 0.2*x[M3i,Mon] :  +Inf :   True
#       2 : 0.16666666666666666 :  0.1111111111111111*x[M3i,Tue] :  +Inf :   True
#       3 : 0.16666666666666666 : 0.09090909090909091*x[M3i,Wed] :  +Inf :   True
#       4 : 0.16666666666666666 : 0.09090909090909091*x[M3i,Thu] :  +Inf :   True
#       5 : 0.16666666666666666 :                 0.1*x[M3i,Fri] :  +Inf :   True
#       6 : 0.16666666666666666 : 0.07692307692307693*x[M3i,Sat] :  +Inf :   True
#       7 : 0.16666666666666666 :              0.0625*x[M3i,Sun] :  +Inf :   True
#       8 : 0.16666666666666666 :                 0.1*x[M3n,Mon] :  +Inf :   True
#       9 : 0.16666666666666666 :                 0.1*x[M3n,Tue] :  +Inf :   True
#      10 : 0.16666666666666666 :  0.1111111111111111*x[M3n,Wed] :  +Inf :   True
#      11 : 0.16666666666666666 :                 0.1*x[M3n,Thu] :  +Inf :   True
#      12 : 0.16666666666666666 :  0.1111111111111111*x[M3n,Fri] :  +Inf :   True
#      13 : 0.16666666666666666 :               0.125*x[M3n,Sat] :  +Inf :   True
#      14 : 0.16666666666666666 :               0.125*x[M3n,Sun] :  +Inf :   True
#      15 : 0.08333333333333333 :                 0.2*x[E3i,Mon] :  +Inf :   True
#      16 : 0.08333333333333333 : 0.14285714285714285*x[E3i,Tue] :  +Inf :   True
#      17 : 0.08333333333333333 :                 0.1*x[E3i,Wed] :  +Inf :   True
#      18 : 0.08333333333333333 : 0.08333333333333333*x[E3i,Thu] :  +Inf :   True
#      19 : 0.08333333333333333 : 0.09090909090909091*x[E3i,Fri] :  +Inf :   True
#      20 : 0.08333333333333333 : 0.06666666666666667*x[E3i,Sat] :  +Inf :   True
#      21 : 0.08333333333333333 : 0.06666666666666667*x[E3i,Sun] :  +Inf :   True
#      22 : 0.08333333333333333 :                 0.1*x[E3n,Mon] :  +Inf :   True
#      23 : 0.08333333333333333 : 0.16666666666666666*x[E3n,Tue] :  +Inf :   True
#      24 : 0.08333333333333333 :  0.1111111111111111*x[E3n,Wed] :  +Inf :   True
#      25 : 0.08333333333333333 :  0.1111111111111111*x[E3n,Thu] :  +Inf :   True
#      26 : 0.08333333333333333 :  0.1111111111111111*x[E3n,Fri] :  +Inf :   True
#      27 : 0.08333333333333333 :               0.125*x[E3n,Sat] :  +Inf :   True
#      28 : 0.08333333333333333 :               0.125*x[E3n,Sun] :  +Inf :   True

# %% [markdown]
# #### 4.4 Solve the linear programming model

# %%
# Instantiate the linear programming algorithm implementation
# that is to be used, can be changed to
# Solver = SolverFactory('glpk'')
Solver = SolverFactory('gurobi')

# Define the dual suffix for the
# next section about Sensitivity
# and Lagrange multipliers
continuous_model.dual = pyo.Suffix(direction = pyo.Suffix.IMPORT)

# Solve the model using the solver
# Start the stopwatch
clock_start = process_time() 
Results = Solver.solve(continuous_model)
clock_stop = process_time()

# Save the results into the results directory
t_results = DataFrame()

# Loop through the result components
# to get the Scenario-Solution pairs
# in order to write them into a csv file
# for further inspection
for v in continuous_model.component_objects(pyo.Var):
    row_names = [pyo.name(v[i]) for i in v]
    row_values = [pyo.value(v[i]) for i in v]

# Forming the Scenario-Solution pairs
t_results = list(map(list, zip(row_names, row_values)))

# Instatiate and define a data frame to store this information
df = DataFrame(t_results, columns=['Scenario', 'Solution (in number of doctors)'])

# Saving the information to a csv file in the results directory
df.to_csv("../results/sol_continuous.csv", mode = "w+")

# Display the Pyomo-[Gurobi/GLPK] solution
print("Elapsed time: ", clock_stop-clock_start) 
continuous_model.x.display()
# Out:
# Elapsed time:  0.0
# x : Number of intensivists
#     Size=84, Index=x_index
#     Key            : Lower : Value               : Upper : Fixed : Stale : Domain
#     ('E1i', 'Fri') :     0 :  1.7857142857142856 :  None : False : False : NonNegativeReals
#     ('E1i', 'Mon') :     0 :                 2.0 :  None : False : False : NonNegativeReals
#     ('E1i', 'Sat') :     0 :                 0.0 :  None : False : False : NonNegativeReals
#     ('E1i', 'Sun') :     0 :                 0.0 :  None : False : False : NonNegativeReals
#     ('E1i', 'Thu') :     0 :   1.857142857142857 :  None : False : False : NonNegativeReals
#     ('E1i', 'Tue') :     0 :  1.7142857142857142 :  None : False : False : NonNegativeReals
#     ('E1i', 'Wed') :     0 :  1.5714285714285714 :  None : False : False : NonNegativeReals
#     ('E1n', 'Fri') :     0 :                 0.5 :  None : False : False : NonNegativeReals
#     ('E1n', 'Mon') :     0 :  0.8571428571428571 :  None : False : False : NonNegativeReals
#     ('E1n', 'Sat') :     0 :                 0.0 :  None : False : False : NonNegativeReals
#     ('E1n', 'Sun') :     0 :                 0.0 :  None : False : False : NonNegativeReals
#     ('E1n', 'Thu') :     0 : 0.42857142857142855 :  None : False : False : NonNegativeReals
#     ('E1n', 'Tue') :     0 :  0.3571428571428571 :  None : False : False : NonNegativeReals
#     ('E1n', 'Wed') :     0 :  0.5714285714285714 :  None : False : False : NonNegativeReals
#     ('E2i', 'Fri') :     0 :                 1.6 :  None : False : False : NonNegativeReals
#     ('E2i', 'Mon') :     0 :                 1.6 :  None : False : False : NonNegativeReals
#     ('E2i', 'Sat') :     0 :                 0.0 :  None : False : False : NonNegativeReals
#     ('E2i', 'Sun') :     0 :                 0.0 :  None : False : False : NonNegativeReals
#     ('E2i', 'Thu') :     0 :  1.7000000000000002 :  None : False : False : NonNegativeReals
#     ('E2i', 'Tue') :     0 :                 1.1 :  None : False : False : NonNegativeReals
#     ('E2i', 'Wed') :     0 :                 1.0 :  None : False : False : NonNegativeReals
#     ('E2n', 'Fri') :     0 :                 0.8 :  None : False : False : NonNegativeReals
#     ('E2n', 'Mon') :     0 :                 1.0 :  None : False : False : NonNegativeReals
#     ('E2n', 'Sat') :     0 :                 0.0 :  None : False : False : NonNegativeReals
#     ('E2n', 'Sun') :     0 :                 0.0 :  None : False : False : NonNegativeReals
#     ('E2n', 'Thu') :     0 :  0.6000000000000001 :  None : False : False : NonNegativeReals
#     ('E2n', 'Tue') :     0 :  0.9000000000000001 :  None : False : False : NonNegativeReals
#     ('E2n', 'Wed') :     0 :  0.9000000000000001 :  None : False : False : NonNegativeReals
#     ('E3i', 'Fri') :     0 :  0.9166666666666666 :  None : False : False : NonNegativeReals
#     ('E3i', 'Mon') :     0 : 0.41666666666666663 :  None : False : False : NonNegativeReals
#     ('E3i', 'Sat') :     0 :                1.25 :  None : False : False : NonNegativeReals
#     ('E3i', 'Sun') :     0 :                1.25 :  None : False : False : NonNegativeReals
#     ('E3i', 'Thu') :     0 :                 1.0 :  None : False : False : NonNegativeReals
#     ('E3i', 'Tue') :     0 :  0.5833333333333334 :  None : False : False : NonNegativeReals
#     ('E3i', 'Wed') :     0 :  0.8333333333333333 :  None : False : False : NonNegativeReals
#     ('E3n', 'Fri') :     0 :                0.75 :  None : False : False : NonNegativeReals
#     ('E3n', 'Mon') :     0 :  0.8333333333333333 :  None : False : False : NonNegativeReals
#     ('E3n', 'Sat') :     0 :  0.6666666666666666 :  None : False : False : NonNegativeReals
#     ('E3n', 'Sun') :     0 :  0.6666666666666666 :  None : False : False : NonNegativeReals
#     ('E3n', 'Thu') :     0 :                0.75 :  None : False : False : NonNegativeReals
#     ('E3n', 'Tue') :     0 :                 0.5 :  None : False : False : NonNegativeReals
#     ('E3n', 'Wed') :     0 :                0.75 :  None : False : False : NonNegativeReals
#     ('M1i', 'Fri') :     0 :   2.142857142857143 :  None : False : False : NonNegativeReals
#     ('M1i', 'Mon') :     0 :  1.7857142857142856 :  None : False : False : NonNegativeReals
#     ('M1i', 'Sat') :     0 :                 0.0 :  None : False : False : NonNegativeReals
#     ('M1i', 'Sun') :     0 :                 0.0 :  None : False : False : NonNegativeReals
#     ('M1i', 'Thu') :     0 :  1.6428571428571428 :  None : False : False : NonNegativeReals
#     ('M1i', 'Tue') :     0 :  1.5714285714285714 :  None : False : False : NonNegativeReals
#     ('M1i', 'Wed') :     0 :  1.2857142857142858 :  None : False : False : NonNegativeReals
#     ('M1n', 'Fri') :     0 :                 0.5 :  None : False : False : NonNegativeReals
#     ('M1n', 'Mon') :     0 :  1.0714285714285714 :  None : False : False : NonNegativeReals
#     ('M1n', 'Sat') :     0 :                 0.0 :  None : False : False : NonNegativeReals
#     ('M1n', 'Sun') :     0 :                 0.0 :  None : False : False : NonNegativeReals
#     ('M1n', 'Thu') :     0 :  0.5714285714285714 :  None : False : False : NonNegativeReals
#     ('M1n', 'Tue') :     0 :  0.5714285714285714 :  None : False : False : NonNegativeReals
#     ('M1n', 'Wed') :     0 :  0.7142857142857142 :  None : False : False : NonNegativeReals
#     ('M2i', 'Fri') :     0 :                 2.0 :  None : False : False : NonNegativeReals
#     ('M2i', 'Mon') :     0 :  1.4000000000000001 :  None : False : False : NonNegativeReals
#     ('M2i', 'Sat') :     0 :  2.4000000000000004 :  None : False : False : NonNegativeReals
#     ('M2i', 'Sun') :     0 :                 2.7 :  None : False : False : NonNegativeReals
#     ('M2i', 'Thu') :     0 :  1.8000000000000003 :  None : False : False : NonNegativeReals
#     ('M2i', 'Tue') :     0 :                 1.0 :  None : False : False : NonNegativeReals
#     ('M2i', 'Wed') :     0 :  1.2000000000000002 :  None : False : False : NonNegativeReals
#     ('M2n', 'Fri') :     0 :                 0.8 :  None : False : False : NonNegativeReals
#     ('M2n', 'Mon') :     0 :  0.9000000000000001 :  None : False : False : NonNegativeReals
#     ('M2n', 'Sat') :     0 :  0.7000000000000001 :  None : False : False : NonNegativeReals
#     ('M2n', 'Sun') :     0 :  0.6000000000000001 :  None : False : False : NonNegativeReals
#     ('M2n', 'Thu') :     0 :  0.7000000000000001 :  None : False : False : NonNegativeReals
#     ('M2n', 'Tue') :     0 :  0.7000000000000001 :  None : False : False : NonNegativeReals
#     ('M2n', 'Wed') :     0 :  0.9000000000000001 :  None : False : False : NonNegativeReals
#     ('M3i', 'Fri') :     0 :  1.6666666666666665 :  None : False : False : NonNegativeReals
#     ('M3i', 'Mon') :     0 :  0.8333333333333333 :  None : False : False : NonNegativeReals
#     ('M3i', 'Sat') :     0 :  2.1666666666666665 :  None : False : False : NonNegativeReals
#     ('M3i', 'Sun') :     0 :  2.6666666666666665 :  None : False : False : NonNegativeReals
#     ('M3i', 'Thu') :     0 :  1.8333333333333333 :  None : False : False : NonNegativeReals
#     ('M3i', 'Tue') :     0 :                 1.5 :  None : False : False : NonNegativeReals
#     ('M3i', 'Wed') :     0 :  1.8333333333333333 :  None : False : False : NonNegativeReals
#     ('M3n', 'Fri') :     0 :                 1.5 :  None : False : False : NonNegativeReals
#     ('M3n', 'Mon') :     0 :  1.6666666666666665 :  None : False : False : NonNegativeReals
#     ('M3n', 'Sat') :     0 :  1.3333333333333333 :  None : False : False : NonNegativeReals
#     ('M3n', 'Sun') :     0 :  1.3333333333333333 :  None : False : False : NonNegativeReals
#     ('M3n', 'Thu') :     0 :  1.6666666666666665 :  None : False : False : NonNegativeReals
#     ('M3n', 'Tue') :     0 :  1.6666666666666665 :  None : False : False : NonNegativeReals
#     ('M3n', 'Wed') :     0 :                 1.5 :  None : False : False : NonNegativeReals

# %% [markdown]
# ### 5. Sensitivities (continuous case)

# %% [markdown]
# Lagrange multipliers are used to obtain the solution of constrained optimization problems. More complex formulations of the Lagrangian theorem that allow for the optimization of continuous functions over convex regions (note that they might not be necessarily smooth). [<a href="#cone-dual">5</a>]
#
# In this more elaborate formulation we are able to accomotade inequality constraints that overcome the limitations of only establishing $\nabla L = 0$ which corresponded to its simplest version.
#
# To sustain this more complex version of the Lagrangian multipliers we introduce a definition that relies on the saddle points of the Lagrangian. We know ought to present the following concepts to better illustrate this new perspective: [<a href="#cone-dual">5</a>]
#
# - For a matrix $V$ whose columns are made up **generators**, vectors $\vec{v_0}, \vec{v_2}, \cdots, \vec{v_{n-1}}$ its **cone** is defined as:
#
# $$cone(V) = \left\{ \vec{c} \in \mathbb{R}^n : \quad \vec{c} = \sum_{k=0}^{n-1}\alpha_k v_k; \quad \alpha_k \in \mathbb{R}^+ \right\}$$
#
# For a vector $\vec{a}$ containing all the $\alpha_k$ and the same matrix $V$ we can rewrite it as:
#
# $$cone(V) = \left\{ \vec{c} \in \mathbb{R}^n : \quad \vec{c} = V \alpha; \quad \alpha \in \mathbb{R}^+ \right\}$$
#
# - For a given cone $C$, its **dual** $C^\perp$ is defined as:
#
# $$C^\perp = \left\{\vec{x} \in \mathbb{R}^m : \quad \vec{x} \cdot \vec{c} \leq 0; \quad \forall \vec{c} \in C \right\}$$
#
# - A cone with the property $C = -C^\perp$ is known as **self-dual**.
#
# A more comprehensive form of the Lagrangian multiplier theorem establishes an equivalence between the problem of finding $\vec{x}$ to minimize a function $f(\vec{x})$ subject to a number of constraints and that of finidng the $\vec{x}$ and $\vec{p}$ that minimize and maximize, respectively, the Lagrangian $L(\vec{x}, \vec{p})$, where $p$ belongs to a cone that happens to be self-dual.
#
# The first problem was called the *linear program*, whereas the second is know as the *dual program*. Because of their behavior, dual variables are sometimes termed **shadow prices** as they represent the change in the objective function optimal value per infinitesimal unit of a given constraint. [<a href="#cone-dual">5</a>]
#
# This is intriscaly related to the concept of **sensitivity** is defined as the *change in the objective function if there is a marginal change in vector b*.

# %%
# After importing the corresponding suffix
# in the previous cell, we display the
# duals/sensitivities per constraint
continuous_model.dual.display()
# Out:
# dual : Direction=Suffix.IMPORT, Datatype=Suffix.FLOAT
#     Key                            : Value
#                maxStaffPerDay[Fri] :   0.0
#                maxStaffPerDay[Mon] :   0.0
#                maxStaffPerDay[Sat] :   0.0
#                maxStaffPerDay[Sun] :   0.0
#                maxStaffPerDay[Thu] :   0.0
#                maxStaffPerDay[Tue] :   0.0
#                maxStaffPerDay[Wed] :   0.0
#      minproportions_firstlevel[10] :   1.0
#      minproportions_firstlevel[11] :   1.0
#      minproportions_firstlevel[12] :   1.0
#      minproportions_firstlevel[13] :   1.0
#      minproportions_firstlevel[14] :   1.0
#      minproportions_firstlevel[15] :   1.0
#      minproportions_firstlevel[16] :   1.0
#      minproportions_firstlevel[17] :   1.0
#      minproportions_firstlevel[18] :   1.0
#      minproportions_firstlevel[19] :   1.0
#       minproportions_firstlevel[1] :   1.0
#      minproportions_firstlevel[20] :   1.0
#       minproportions_firstlevel[2] :   1.0
#       minproportions_firstlevel[3] :   1.0
#       minproportions_firstlevel[4] :   1.0
#       minproportions_firstlevel[5] :   1.0
#       minproportions_firstlevel[6] :   1.0
#       minproportions_firstlevel[7] :   1.0
#       minproportions_firstlevel[8] :   1.0
#       minproportions_firstlevel[9] :   1.0
#     minproportions_secondlevel[10] :   1.0
#     minproportions_secondlevel[11] :   1.0
#     minproportions_secondlevel[12] :   1.0
#     minproportions_secondlevel[13] :   1.0
#     minproportions_secondlevel[14] :   1.0
#     minproportions_secondlevel[15] :   1.0
#     minproportions_secondlevel[16] :   1.0
#     minproportions_secondlevel[17] :   1.0
#     minproportions_secondlevel[18] :   1.0
#     minproportions_secondlevel[19] :   1.0
#      minproportions_secondlevel[1] :   1.0
#     minproportions_secondlevel[20] :   1.0
#     minproportions_secondlevel[21] :   1.0
#     minproportions_secondlevel[22] :   1.0
#     minproportions_secondlevel[23] :   1.0
#     minproportions_secondlevel[24] :   1.0
#      minproportions_secondlevel[2] :   1.0
#      minproportions_secondlevel[3] :   1.0
#      minproportions_secondlevel[4] :   1.0
#      minproportions_secondlevel[5] :   1.0
#      minproportions_secondlevel[6] :   1.0
#      minproportions_secondlevel[7] :   1.0
#      minproportions_secondlevel[8] :   1.0
#      minproportions_secondlevel[9] :   1.0
#      minproportions_thirdlevel[10] :   1.0
#      minproportions_thirdlevel[11] :   1.0
#      minproportions_thirdlevel[12] :   1.0
#      minproportions_thirdlevel[13] :   1.0
#      minproportions_thirdlevel[14] :   1.0
#      minproportions_thirdlevel[15] :   1.0
#      minproportions_thirdlevel[16] :   1.0
#      minproportions_thirdlevel[17] :   1.0
#      minproportions_thirdlevel[18] :   1.0
#      minproportions_thirdlevel[19] :   1.0
#       minproportions_thirdlevel[1] :   1.0
#      minproportions_thirdlevel[20] :   1.0
#      minproportions_thirdlevel[21] :   1.0
#      minproportions_thirdlevel[22] :   1.0
#      minproportions_thirdlevel[23] :   1.0
#      minproportions_thirdlevel[24] :   1.0
#      minproportions_thirdlevel[25] :   1.0
#      minproportions_thirdlevel[26] :   1.0
#      minproportions_thirdlevel[27] :   1.0
#      minproportions_thirdlevel[28] :   1.0
#       minproportions_thirdlevel[2] :   1.0
#       minproportions_thirdlevel[3] :   1.0
#       minproportions_thirdlevel[4] :   1.0
#       minproportions_thirdlevel[5] :   1.0
#       minproportions_thirdlevel[6] :   1.0
#       minproportions_thirdlevel[7] :   1.0
#       minproportions_thirdlevel[8] :   1.0
#       minproportions_thirdlevel[9] :   1.0
#         weekendrules_firstlevel[1] :   0.0
#         weekendrules_firstlevel[2] :   0.0
#         weekendrules_firstlevel[3] :   0.0
#         weekendrules_firstlevel[4] :   0.0
#         weekendrules_firstlevel[5] :   0.0
#         weekendrules_firstlevel[6] :   0.0
#         weekendrules_firstlevel[7] :   0.0
#         weekendrules_firstlevel[8] :   0.0
#        weekendrules_secondlevel[1] :   0.0
#        weekendrules_secondlevel[2] :   0.0
#        weekendrules_secondlevel[3] :   0.0
#        weekendrules_secondlevel[4] :   0.0

# %% [markdown]
# It is possible to see that all the *maxStaffPerDay* and *weekednrules* constraints have duals equal to zero. This results is reiforced by the fact that these constraints are defined as equalities that are to be strictly respected, whereas the ones that are non-zero, in this case equal to 1 are those corresponding to the *minproportions* which are established as inequalities.
#
# In this case, for each one of the *minproportions* constraints, it can be interpreted that an increase in the number of staff in a given scenario, through an increase in the ratio, delivers a unit improvement to the overall objective function. It is clear know why this is not the case in the *maxStaffPerDay* and *weekendrules* cases, as the objective function is not improved by any modification in this sense.

# %% [markdown]
# ### 6. Model Overview (discrete Case)
#
# #### 6.1 General conditions
#
# In the discrete case we will be employing binary variables to represent the scheduling problem that a hospital manager may be interested in solving in order to best respond to a disease outbreak by providing the best medical care in term of Intensivist-to-Patient ratios and medical staff work safety, namely in the case of rest hours as mandated by European and Spanish law. Unlike the continous case, we will be enforcing these restrictions through explicit constraints.
#
# The objective fucntion will be very similar as we strive minimze the difference between the actual Intensivist-to-Patient ratio and the optimal one as determined by the Spanish Health Ministry.
#
# Except when noted, the general conditions that were laid out in the continuous case still hold true for the discrete one.
#
# We define the following three vectors:
#
# - Vector of physicians (binary): $$\vec{G} = (g_0, g_1, \cdots, g_{P-1})$$
# - Vector of days of the week: $$\vec{D} = (d_0, d_1, \cdots, d_{M-1})$$
# - Vector of scenarios: $$\vec{S} = (s_0, s_1, \cdots, s_{N-1})$$
#
# It follows from the initial problem formulation that $P = 17$, $M = 7$ and $N = 12$.
#
# #### 6.2 Specific conditions
#
# Our model will try to minimize the difference between the actual Intensivist-to-Patient ratio and the optimal one that is defined by the Spanish Ministry of Health. This will be achieved by assigning a variable number $x$ of physicians to a given turn for either the Infectious Section and the Non-Infectious Section of the UCI. This model would be of use in the first week of the outbreak where new physicians have not arrived yet.
#
# To better accomodate this problem, the two daily shift per scenario were chosen to last 12 hours each, as a sensible compromise between the 10 hour and 14 hour duration of the morning and evening shifts, respectively, set by the Spanish Health Ministry guidelines. It is worth noting that these twelve hour shifts include the necessary breaks for rest and food.
#
# **Decision variables**
#
# Decision variables $x_{i,j,k}$ will be representing whether a given physician $i$ is working at a given day $j$ and shift $k$ or not; it is a binary variable where $1$ indicates that the doctor is working and $0$ that he/she is resting.
#
# Unlike in the previous case where the shift and level information were squashed so as to be able to represent the problem in a 2D manner with a matrix, this will not be possible in this instance.
#
# **Constraints**
#
# Constraints from the continuous case will continue to be valid under certain modifications. To these constraints we add the following requirements:
#
# - Doctors will not work more than 48 hours per week, i.e, 4 shifts per week.
#
# - The resting time between two shifts is 12 hours, i.e., one shift.
#
# According to the European Directive 2003/88/CE of November 4, 2003; a limit of 48 weekly work hours is established. [<a href="#2003/88/CE">6</a>] The maximum weekly work hours were chosen for this optimization problem are they refer to a unique week during an epidemic outbreak and it includes the on duty shift that physicians usually take (except when they have a certain age or health conditions).

# %% [markdown]
# ### 7. General formulation (discrete case)
#
# - **Decision variables**: *Present*, a binary variable that represents whether a particular physician $i$ will be working on day $j$ at shift $k$. Mathematically:
#
# $$
#     x_{ijk} =
#
#     \begin{cases}
#         \text{1,} &\quad \text{Intensivist } i \text{ working on day } j \text{ in shift } k \\
#         \text{0,} &\quad \text{otherwise.}
#     \end{cases}
#
#     \quad \forall i, j, k
# $$
#
# - **Objective function**: <span style="color:red">Minimize</span> the difference between the optimal Intensivist-to-Patient ratio set by the Spanish Ministry of Health and the actual one in the first week of the outbreak response.
#
# $$\min_{x_{ijk}} \sum_{j=0}^{M-1}{\sum_{k=0}^{N-1}\left(\frac{x_{jk}}{p_{jk}}-r_{k}\right)}$$
#
# where: $$x_{jk} = \sum_{i=0}^{P-1} x_{ijk} \quad \forall i$$ for a given $j$ and $k$.
#
# even more concisely:
#
# $$\sum_{j=0}^{M-1}\sum_{k=0}^{N-1}\left(\frac{\sum_{i=0}^{P-1} x_{ijk}}{p_{jk}}-r_k\right)$$
#
# - **Constraints**:
#
# - No more than 48 hours worked per week per physician, i.e., no more than 4 shifts per week per physician:
#  $$\sum_{j=0}^{M-1}\sum_{k=0}^{N-1} x_{ijk} \leq 4, \quad \forall i$$
#
#  - Minimum rest period of 12 hours between two shifts per physician, i.e., minimum rest period of one shift between two shifts per physician:
#  $$\sum_{k=0}^{N-1} x_{ijk} \leq 1, \quad \forall i, j$$
#
#  - The number of doctors $x_{ijk}$ for Level I is 0 on weekends.
#
#  $$\sum_{i=0}^{P-1} x_{i,5,k} = 0, \text{ for } k = 0, 3, 6, 9$$
#
#  $$\sum_{i=0}^{P-1} x_{i,6,k} = 0, \text{ for } k = 0, 3, 6, 9$$
#
#  - The number of doctors $x_{ijk}$ for Level II is 0 on the evening shift during the weekends.
#
#  $$\sum_{i=0}^{P-1} x_{i,5,k} = 0 \text{ for } k = 4, 10$$
#  $$\sum_{i=0}^{P-1} x_{i,6,k} = 0 \text{ for } k = 4, 10$$
#
#  - There must be at least 1 doctor per 14 patients on Level I (except weekends)
#
#  $$\frac{\sum_{i=0}^{P-1} x_{i,j,k}}{p_{jk}} \geq \frac{1}{14} \text{ for } j = 0, 1, 2, 3, 4 \text{ and } k = 0, 3, 6, 9$$
#
#  - There must be at least 1 doctor per 10 patients on Level II (except weekend evenings)
#
#  $$\frac{\sum_{i=0}^{P-1} x_{i,j,k}}{p_{jk}} \geq \frac{1}{10} \text{ for } j = 0, 1, 2, 3, 4, 5, 6 \text{ and } k = 1, 4, 7, 10$$
#
#  - There must be at least 1 doctor per 6 patients on Level III during the morning shift.
#
#  $$\frac{\sum_{i=0}^{P-1} x_{i,j,k}}{p_{jk}} \geq \frac{1}{6} \text{ for } j = 0, 1, 2, 3, 4, 5, 6 \text{ and } k = 2, 8$$
#
#  - There must be at least 1 doctor per 12 patients on Level III during the evening shift.
#
#  $$\frac{\sum_{i=0}^{P-1} x_{i,j,k}}{p_{jk}} \geq \frac{1}{12} \text{ for } j = 0, 1, 2, 3, 4, 5, 6 \text{ and } k = 5, 11$$
#
# - The decision variables $x_{ijk}$ are binary:
# $$x_{ijk} \in \{0,1\} \quad \forall i,j,k$$

# %% [markdown]
# ### 8. Implementation (discrete case)

# %%
# %reset -f

# We reset environment variables
# to avoid reference errors

# %%
# We import the libraries that are needed
# for solving linear programming problems
import pyomo.environ as pyo
from pyomo.opt import SolverFactory

# For performance analysis purposes
from time import process_time

# For saving the results returned by the solver
from pandas import Series, DataFrame

# For better code readability and maintanability
from typing import Final

# Define the constants
NUMBER_OF_INTENSIVISTS: Final = 24
WEEK: Final = ['Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun']
WEEKDAYS: Final = WEEK[:5]
WEEKEND: Final = WEEK[-2:]
SHIFTS: Final = [
    'M1i', 'M2i', 'M3i',
    'E1i', 'E2i', 'E3i', 
    'M1n', 'M2n', 'M3n',
    'E1n', 'E2n', 'E3n'
    ]

# %% [markdown]
# #### 8.0 Problem data definition: sets and parameters

# %%
# We define the discrete model
discrete_model = pyo.ConcreteModel('Discrete model')

# i dimension : List of physicians
i_labels = ['G' + str(i) for i in range(NUMBER_OF_INTENSIVISTS)]

# We check that the length of the 1st dimension
# is equal to NUMBER_OF_INTENSIVISTS
assert len(i_labels) == NUMBER_OF_INTENSIVISTS

# j dimension : List of days of the week
j_labels = WEEK

# We check that the length of the 2nd dimension
# is equal to 7
assert len(j_labels) == 7

# k dimension: List of shifts
# there are 12 shifts of 12 hour each
k_labels = SHIFTS

# We check that the length of the 3rd dimension
# is equal to 12
assert len(k_labels) == 12

# Dictionary that stores the (day,shift_list)
k_dict = {day: k_labels for day in j_labels}

# Check that the number of k_labels is equal
# to the theoretical result of 7 * 12 = 84
count = 0
for item in k_dict.items():
    count += len(item[1])
assert count == len(WEEK)*len(SHIFTS)

# We initialize the model dimensions with the labels
# that were defined above
discrete_model.i = pyo.Set(initialize = i_labels, doc = "physicians")
discrete_model.j = pyo.Set(initialize = j_labels, doc = "days of the week")
discrete_model.k = pyo.Set(initialize = k_labels, doc = "scenarios")

patient_forecast = {

    # In-Python used notation:
    # M <- morning shift; E <- evening shift
    # 1, 2, 3 <- Assistance Level
    # i <- infectious; n <- non-infectious

    ('Mon','M1i'): 25,
    ('Tue','M1i'): 22,
    ('Wed','M1i'): 18,
    ('Thu','M1i'): 23,
    ('Fri','M1i'): 30,
    ('Sat','M1i'): 33,
    ('Sun','M1i'): 38,

    ('Mon','M2i'): 14,
    ('Tue','M2i'): 10,
    ('Wed','M2i'): 12,
    ('Thu','M2i'): 18,
    ('Fri','M2i'): 20,
    ('Sat','M2i'): 24,
    ('Sun','M2i'): 27,

    ('Mon','M3i'): 5,
    ('Tue','M3i'): 9,
    ('Wed','M3i'): 11,
    ('Thu','M3i'): 11,
    ('Fri','M3i'): 10,
    ('Sat','M3i'): 13,
    ('Sun','M3i'): 16,

    ('Mon','E1i'): 28,
    ('Tue','E1i'): 24,
    ('Wed','E1i'): 22,
    ('Thu','E1i'): 26,
    ('Fri','E1i'): 25,
    ('Sat','E1i'): 35,
    ('Sun','E1i'): 39,

    ('Mon','E2i'): 16,
    ('Tue','E2i'): 11,
    ('Wed','E2i'): 10,
    ('Thu','E2i'): 17,
    ('Fri','E2i'): 16,
    ('Sat','E2i'): 26,
    ('Sun','E2i'): 29,

    ('Mon','E3i'): 5,
    ('Tue','E3i'): 7,
    ('Wed','E3i'): 10,
    ('Thu','E3i'): 12,
    ('Fri','E3i'): 11,
    ('Sat','E3i'): 15,
    ('Sun','E3i'): 15,

    ('Mon','M1n'): 15,
    ('Tue','M1n'): 8,
    ('Wed','M1n'): 10,
    ('Thu','M1n'): 8,
    ('Fri','M1n'): 7,
    ('Sat','M1n'): 6,
    ('Sun','M1n'): 5,

    ('Mon','M2n'): 9,
    ('Tue','M2n'): 7,
    ('Wed','M2n'): 9,
    ('Thu','M2n'): 7,
    ('Fri','M2n'): 8,
    ('Sat','M2n'): 7,
    ('Sun','M2n'): 6,

    ('Mon','M3n'): 10,
    ('Tue','M3n'): 10,
    ('Wed','M3n'): 9,
    ('Thu','M3n'): 10,
    ('Fri','M3n'): 9,
    ('Sat','M3n'): 8,
    ('Sun','M3n'): 8,

    ('Mon','E1n'): 12,
    ('Tue','E1n'): 5,
    ('Wed','E1n'): 8,
    ('Thu','E1n'): 6,
    ('Fri','E1n'): 7,
    ('Sat','E1n'): 5,
    ('Sun','E1n'): 4,

    ('Mon','E2n'): 10,
    ('Tue','E2n'): 9,
    ('Wed','E2n'): 9,
    ('Thu','E2n'): 6,
    ('Fri','E2n'): 8,
    ('Sat','E2n'): 7,
    ('Sun','E2n'): 7,

    ('Mon','E3n'): 10,
    ('Tue','E3n'): 6,
    ('Wed','E3n'): 9,
    ('Thu','E3n'): 9,
    ('Fri','E3n'): 9,
    ('Sat','E3n'): 8,
    ('Sun','E3n'): 8
    
}

# We check the length of matrix
# to be equal to 84 (7 x 12)
assert len(patient_forecast.items()) == len(WEEK)*len(SHIFTS)

# We define the forecasted number of patients per scenario
# days of the week into the model. This information is
# crucial in the solution to the problem
discrete_model.patients = pyo.Param(discrete_model.j, discrete_model.k,
initialize = patient_forecast, doc = "Forecasted patients per scenario and day of the week")

# Print the basic parts of the discrete model
#discrete_model.pprint()

# %% [markdown]
# #### 8.1 Define the variables

# %%
# We declare the x_ijk variables of the model
# these variables are binary and 
# are initialize at the beginning as 0
# which means "not present"
discrete_model.x = pyo.Var(
                            discrete_model.i, discrete_model.j, discrete_model.k,
                            doc = "Present",
                            domain = pyo.Binary
                            )

# Print the variables x_ijk
# that were created
print(discrete_model.x.display())

# Check that the number of x_ijk variables
# coincides with the theorical result
# of 17 * 7 * 12 = 1428
assert len(list(discrete_model.x.keys())) == NUMBER_OF_INTENSIVISTS * len(WEEK) * len(SHIFTS)

"""
# Other version
discrete_model.x = pyo.Var(
                                    ((physician, day, shift) for physician in i_labels for day in j_labels for shift in k_dict[day]),
                                    within = pyo.Binary,
                                    initialize = 0,
                                    doc = "Present"
                                    )

# Print the variables x_ijk
# that were created
print(discrete_model.x.display())

# Check that the number of x_ijk variables
# coincides with the theorical result
# of 17 * 7 * 12 = 1428
assert len(list(discrete_model.x.keys())) == NUMBER_OF_INTENSIVISTS * len(WEEK) * len(SHIFTS)
"""
# Out:
# x : Present
#     Size=2016, Index=x_index
#     Key                   : Lower : Value : Upper : Fixed : Stale : Domain
#      ('G0', 'Fri', 'E1i') :     0 :  None :     1 : False :  True : Binary
#      ('G0', 'Fri', 'E1n') :     0 :  None :     1 : False :  True : Binary
#      ('G0', 'Fri', 'E2i') :     0 :  None :     1 : False :  True : Binary
#      ('G0', 'Fri', 'E2n') :     0 :  None :     1 : False :  True : Binary
#      ('G0', 'Fri', 'E3i') :     0 :  None :     1 : False :  True : Binary
#      ('G0', 'Fri', 'E3n') :     0 :  None :     1 : False :  True : Binary
#      ('G0', 'Fri', 'M1i') :     0 :  None :     1 : False :  True : Binary
#      ('G0', 'Fri', 'M1n') :     0 :  None :     1 : False :  True : Binary
#      ('G0', 'Fri', 'M2i') :     0 :  None :     1 : False :  True : Binary
#      ('G0', 'Fri', 'M2n') :     0 :  None :     1 : False :  True : Binary
#      ('G0', 'Fri', 'M3i') :     0 :  None :     1 : False :  True : Binary
#      ('G0', 'Fri', 'M3n') :     0 :  None :     1 : False :  True : Binary
#      ('G0', 'Mon', 'E1i') :     0 :  None :     1 : False :  True : Binary
#      ('G0', 'Mon', 'E1n') :     0 :  None :     1 : False :  True : Binary
#      ('G0', 'Mon', 'E2i') :     0 :  None :     1 : False :  True : Binary
#      ('G0', 'Mon', 'E2n') :     0 :  None :     1 : False :  True : Binary
#      ('G0', 'Mon', 'E3i') :     0 :  None :     1 : False :  True : Binary
#      ('G0', 'Mon', 'E3n') :     0 :  None :     1 : False :  True : Binary
#      ('G0', 'Mon', 'M1i') :     0 :  None :     1 : False :  True : Binary
#      ('G0', 'Mon', 'M1n') :     0 :  None :     1 : False :  True : Binary
#      ('G0', 'Mon', 'M2i') :     0 :  None :     1 : False :  True : Binary
#      ('G0', 'Mon', 'M2n') :     0 :  None :     1 : False :  True : Binary
#      ('G0', 'Mon', 'M3i') :     0 :  None :     1 : False :  True : Binary
#      ('G0', 'Mon', 'M3n') :     0 :  None :     1 : False :  True : Binary
#      ('G0', 'Sat', 'E1i') :     0 :  None :     1 : False :  True : Binary
#      ('G0', 'Sat', 'E1n') :     0 :  None :     1 : False :  True : Binary
#      ('G0', 'Sat', 'E2i') :     0 :  None :     1 : False :  True : Binary
#      ('G0', 'Sat', 'E2n') :     0 :  None :     1 : False :  True : Binary
#      ('G0', 'Sat', 'E3i') :     0 :  None :     1 : False :  True : Binary
#      ('G0', 'Sat', 'E3n') :     0 :  None :     1 : False :  True : Binary
#      ('G0', 'Sat', 'M1i') :     0 :  None :     1 : False :  True : Binary
#      ('G0', 'Sat', 'M1n') :     0 :  None :     1 : False :  True : Binary
#      ('G0', 'Sat', 'M2i') :     0 :  None :     1 : False :  True : Binary
#      ('G0', 'Sat', 'M2n') :     0 :  None :     1 : False :  True : Binary
#      ('G0', 'Sat', 'M3i') :     0 :  None :     1 : False :  True : Binary
#      ('G0', 'Sat', 'M3n') :     0 :  None :     1 : False :  True : Binary
#      ('G0', 'Sun', 'E1i') :     0 :  None :     1 : False :  True : Binary
#      ('G0', 'Sun', 'E1n') :     0 :  None :     1 : False :  True : Binary
#      ('G0', 'Sun', 'E2i') :     0 :  None :     1 : False :  True : Binary
#      ('G0', 'Sun', 'E2n') :     0 :  None :     1 : False :  True : Binary
#      ('G0', 'Sun', 'E3i') :     0 :  None :     1 : False :  True : Binary
#      ('G0', 'Sun', 'E3n') :     0 :  None :     1 : False :  True : Binary
#      ('G0', 'Sun', 'M1i') :     0 :  None :     1 : False :  True : Binary
#      ('G0', 'Sun', 'M1n') :     0 :  None :     1 : False :  True : Binary
#      ('G0', 'Sun', 'M2i') :     0 :  None :     1 : False :  True : Binary
#      ('G0', 'Sun', 'M2n') :     0 :  None :     1 : False :  True : Binary
#      ('G0', 'Sun', 'M3i') :     0 :  None :     1 : False :  True : Binary
#      ('G0', 'Sun', 'M3n') :     0 :  None :     1 : False :  True : Binary
#      ('G0', 'Thu', 'E1i') :     0 :  None :     1 : False :  True : Binary
#      ('G0', 'Thu', 'E1n') :     0 :  None :     1 : False :  True : Binary
#      ('G0', 'Thu', 'E2i') :     0 :  None :     1 : False :  True : Binary
#      ('G0', 'Thu', 'E2n') :     0 :  None :     1 : False :  True : Binary
#      ('G0', 'Thu', 'E3i') :     0 :  None :     1 : False :  True : Binary
#      ('G0', 'Thu', 'E3n') :     0 :  None :     1 : False :  True : Binary
#      ('G0', 'Thu', 'M1i') :     0 :  None :     1 : False :  True : Binary
#      ('G0', 'Thu', 'M1n') :     0 :  None :     1 : False :  True : Binary
#      ('G0', 'Thu', 'M2i') :     0 :  None :     1 : False :  True : Binary
#      ('G0', 'Thu', 'M2n') :     0 :  None :     1 : False :  True : Binary
#      ('G0', 'Thu', 'M3i') :     0 :  None :     1 : False :  True : Binary
#      ('G0', 'Thu', 'M3n') :     0 :  None :     1 : False :  True : Binary
#      ('G0', 'Tue', 'E1i') :     0 :  None :     1 : False :  True : Binary
#      ('G0', 'Tue', 'E1n') :     0 :  None :     1 : False :  True : Binary
#      ('G0', 'Tue', 'E2i') :     0 :  None :     1 : False :  True : Binary
#      ('G0', 'Tue', 'E2n') :     0 :  None :     1 : False :  True : Binary
#      ('G0', 'Tue', 'E3i') :     0 :  None :     1 : False :  True : Binary
#      ('G0', 'Tue', 'E3n') :     0 :  None :     1 : False :  True : Binary
#      ('G0', 'Tue', 'M1i') :     0 :  None :     1 : False :  True : Binary
#      ('G0', 'Tue', 'M1n') :     0 :  None :     1 : False :  True : Binary
#      ('G0', 'Tue', 'M2i') :     0 :  None :     1 : False :  True : Binary
#      ('G0', 'Tue', 'M2n') :     0 :  None :     1 : False :  True : Binary
#      ('G0', 'Tue', 'M3i') :     0 :  None :     1 : False :  True : Binary
#      ('G0', 'Tue', 'M3n') :     0 :  None :     1 : False :  True : Binary
#      ('G0', 'Wed', 'E1i') :     0 :  None :     1 : False :  True : Binary
#      ('G0', 'Wed', 'E1n') :     0 :  None :     1 : False :  True : Binary
#      ('G0', 'Wed', 'E2i') :     0 :  None :     1 : False :  True : Binary
#      ('G0', 'Wed', 'E2n') :     0 :  None :     1 : False :  True : Binary
#      ('G0', 'Wed', 'E3i') :     0 :  None :     1 : False :  True : Binary
#      ('G0', 'Wed', 'E3n') :     0 :  None :     1 : False :  True : Binary
#      ('G0', 'Wed', 'M1i') :     0 :  None :     1 : False :  True : Binary
#      ('G0', 'Wed', 'M1n') :     0 :  None :     1 : False :  True : Binary
#      ('G0', 'Wed', 'M2i') :     0 :  None :     1 : False :  True : Binary
#      ('G0', 'Wed', 'M2n') :     0 :  None :     1 : False :  True : Binary
#      ('G0', 'Wed', 'M3i') :     0 :  None :     1 : False :  True : Binary
#      ('G0', 'Wed', 'M3n') :     0 :  None :     1 : False :  True : Binary
#      ('G1', 'Fri', 'E1i') :     0 :  None :     1 : False :  True : Binary
#      ('G1', 'Fri', 'E1n') :     0 :  None :     1 : False :  True : Binary
#      ('G1', 'Fri', 'E2i') :     0 :  None :     1 : False :  True : Binary
#      ('G1', 'Fri', 'E2n') :     0 :  None :     1 : False :  True : Binary
#      ('G1', 'Fri', 'E3i') :     0 :  None :     1 : False :  True : Binary
#      ('G1', 'Fri', 'E3n') :     0 :  None :     1 : False :  True : Binary
#      ('G1', 'Fri', 'M1i') :     0 :  None :     1 : False :  True : Binary
#      ('G1', 'Fri', 'M1n') :     0 :  None :     1 : False :  True : Binary
#      ('G1', 'Fri', 'M2i') :     0 :  None :     1 : False :  True : Binary
#      ('G1', 'Fri', 'M2n') :     0 :  None :     1 : False :  True : Binary
#      ('G1', 'Fri', 'M3i') :     0 :  None :     1 : False :  True : Binary
#      ('G1', 'Fri', 'M3n') :     0 :  None :     1 : False :  True : Binary
#      ('G1', 'Mon', 'E1i') :     0 :  None :     1 : False :  True : Binary
#      ('G1', 'Mon', 'E1n') :     0 :  None :     1 : False :  True : Binary
#      ('G1', 'Mon', 'E2i') :     0 :  None :     1 : False :  True : Binary
#      ('G1', 'Mon', 'E2n') :     0 :  None :     1 : False :  True : Binary
#      ('G1', 'Mon', 'E3i') :     0 :  None :     1 : False :  True : Binary
#      ('G1', 'Mon', 'E3n') :     0 :  None :     1 : False :  True : Binary
#      ('G1', 'Mon', 'M1i') :     0 :  None :     1 : False :  True : Binary
#      ('G1', 'Mon', 'M1n') :     0 :  None :     1 : False :  True : Binary
#      ('G1', 'Mon', 'M2i') :     0 :  None :     1 : False :  True : Binary
#      ('G1', 'Mon', 'M2n') :     0 :  None :     1 : False :  True : Binary
#      ('G1', 'Mon', 'M3i') :     0 :  None :     1 : False :  True : Binary
#      ('G1', 'Mon', 'M3n') :     0 :  None :     1 : False :  True : Binary
#      ('G1', 'Sat', 'E1i') :     0 :  None :     1 : False :  True : Binary
#      ('G1', 'Sat', 'E1n') :     0 :  None :     1 : False :  True : Binary
#      ('G1', 'Sat', 'E2i') :     0 :  None :     1 : False :  True : Binary
#      ('G1', 'Sat', 'E2n') :     0 :  None :     1 : False :  True : Binary
#      ('G1', 'Sat', 'E3i') :     0 :  None :     1 : False :  True : Binary
#      ('G1', 'Sat', 'E3n') :     0 :  None :     1 : False :  True : Binary
#      ('G1', 'Sat', 'M1i') :     0 :  None :     1 : False :  True : Binary
#      ('G1', 'Sat', 'M1n') :     0 :  None :     1 : False :  True : Binary
#      ('G1', 'Sat', 'M2i') :     0 :  None :     1 : False :  True : Binary
#      ('G1', 'Sat', 'M2n') :     0 :  None :     1 : False :  True : Binary
#      ('G1', 'Sat', 'M3i') :     0 :  None :     1 : False :  True : Binary
#      ('G1', 'Sat', 'M3n') :     0 :  None :     1 : False :  True : Binary
#      ('G1', 'Sun', 'E1i') :     0 :  None :     1 : False :  True : Binary
#      ('G1', 'Sun', 'E1n') :     0 :  None :     1 : False :  True : Binary
#      ('G1', 'Sun', 'E2i') :     0 :  None :     1 : False :  True : Binary
#      ('G1', 'Sun', 'E2n') :     0 :  None :     1 : False :  True : Binary
#      ('G1', 'Sun', 'E3i') :     0 :  None :     1 : False :  True : Binary
#      ('G1', 'Sun', 'E3n') :     0 :  None :     1 : False :  True : Binary
#      ('G1', 'Sun', 'M1i') :     0 :  None :     1 : False :  True : Binary
#      ('G1', 'Sun', 'M1n') :     0 :  None :     1 : False :  True : Binary
#      ('G1', 'Sun', 'M2i') :     0 :  None :     1 : False :  True : Binary
#      ('G1', 'Sun', 'M2n') :     0 :  None :     1 : False :  True : Binary
#      ('G1', 'Sun', 'M3i') :     0 :  None :     1 : False :  True : Binary
#      ('G1', 'Sun', 'M3n') :     0 :  None :     1 : False :  True : Binary
#      ('G1', 'Thu', 'E1i') :     0 :  None :     1 : False :  True : Binary
#      ('G1', 'Thu', 'E1n') :     0 :  None :     1 : False :  True : Binary
#      ('G1', 'Thu', 'E2i') :     0 :  None :     1 : False :  True : Binary
#      ('G1', 'Thu', 'E2n') :     0 :  None :     1 : False :  True : Binary
#      ('G1', 'Thu', 'E3i') :     0 :  None :     1 : False :  True : Binary
#      ('G1', 'Thu', 'E3n') :     0 :  None :     1 : False :  True : Binary
#      ('G1', 'Thu', 'M1i') :     0 :  None :     1 : False :  True : Binary
#      ('G1', 'Thu', 'M1n') :     0 :  None :     1 : False :  True : Binary
#      ('G1', 'Thu', 'M2i') :     0 :  None :     1 : False :  True : Binary
#      ('G1', 'Thu', 'M2n') :     0 :  None :     1 : False :  True : Binary
#      ('G1', 'Thu', 'M3i') :     0 :  None :     1 : False :  True : Binary
#      ('G1', 'Thu', 'M3n') :     0 :  None :     1 : False :  True : Binary
#      ('G1', 'Tue', 'E1i') :     0 :  None :     1 : False :  True : Binary
#      ('G1', 'Tue', 'E1n') :     0 :  None :     1 : False :  True : Binary
#      ('G1', 'Tue', 'E2i') :     0 :  None :     1 : False :  True : Binary
#      ('G1', 'Tue', 'E2n') :     0 :  None :     1 : False :  True : Binary
#      ('G1', 'Tue', 'E3i') :     0 :  None :     1 : False :  True : Binary
#      ('G1', 'Tue', 'E3n') :     0 :  None :     1 : False :  True : Binary
#      ('G1', 'Tue', 'M1i') :     0 :  None :     1 : False :  True : Binary
#      ('G1', 'Tue', 'M1n') :     0 :  None :     1 : False :  True : Binary
#      ('G1', 'Tue', 'M2i') :     0 :  None :     1 : False :  True : Binary
#      ('G1', 'Tue', 'M2n') :     0 :  None :     1 : False :  True : Binary
#      ('G1', 'Tue', 'M3i') :     0 :  None :     1 : False :  True : Binary
#      ('G1', 'Tue', 'M3n') :     0 :  None :     1 : False :  True : Binary
#      ('G1', 'Wed', 'E1i') :     0 :  None :     1 : False :  True : Binary
#      ('G1', 'Wed', 'E1n') :     0 :  None :     1 : False :  True : Binary
#      ('G1', 'Wed', 'E2i') :     0 :  None :     1 : False :  True : Binary
#      ('G1', 'Wed', 'E2n') :     0 :  None :     1 : False :  True : Binary
#      ('G1', 'Wed', 'E3i') :     0 :  None :     1 : False :  True : Binary
#      ('G1', 'Wed', 'E3n') :     0 :  None :     1 : False :  True : Binary
#      ('G1', 'Wed', 'M1i') :     0 :  None :     1 : False :  True : Binary
#      ('G1', 'Wed', 'M1n') :     0 :  None :     1 : False :  True : Binary
#      ('G1', 'Wed', 'M2i') :     0 :  None :     1 : False :  True : Binary
#      ('G1', 'Wed', 'M2n') :     0 :  None :     1 : False :  True : Binary
#      ('G1', 'Wed', 'M3i') :     0 :  None :     1 : False :  True : Binary
#      ('G1', 'Wed', 'M3n') :     0 :  None :     1 : False :  True : Binary
#     ('G10', 'Fri', 'E1i') :     0 :  None :     1 : False :  True : Binary
#     ('G10', 'Fri', 'E1n') :     0 :  None :     1 : False :  True : Binary
#     ('G10', 'Fri', 'E2i') :     0 :  None :     1 : False :  True : Binary
#     ('G10', 'Fri', 'E2n') :     0 :  None :     1 : False :  True : Binary
#     ('G10', 'Fri', 'E3i') :     0 :  None :     1 : False :  True : Binary
#     ('G10', 'Fri', 'E3n') :     0 :  None :     1 : False :  True : Binary
#     ('G10', 'Fri', 'M1i') :     0 :  None :     1 : False :  True : Binary
#     ('G10', 'Fri', 'M1n') :     0 :  None :     1 : False :  True : Binary
#     ('G10', 'Fri', 'M2i') :     0 :  None :     1 : False :  True : Binary
#     ('G10', 'Fri', 'M2n') :     0 :  None :     1 : False :  True : Binary
#     ('G10', 'Fri', 'M3i') :     0 :  None :     1 : False :  True : Binary
#     ('G10', 'Fri', 'M3n') :     0 :  None :     1 : False :  True : Binary
#     ('G10', 'Mon', 'E1i') :     0 :  None :     1 : False :  True : Binary
#     ('G10', 'Mon', 'E1n') :     0 :  None :     1 : False :  True : Binary
#     ('G10', 'Mon', 'E2i') :     0 :  None :     1 : False :  True : Binary
#     ('G10', 'Mon', 'E2n') :     0 :  None :     1 : False :  True : Binary
#     ('G10', 'Mon', 'E3i') :     0 :  None :     1 : False :  True : Binary
#     ('G10', 'Mon', 'E3n') :     0 :  None :     1 : False :  True : Binary
#     ('G10', 'Mon', 'M1i') :     0 :  None :     1 : False :  True : Binary
#     ('G10', 'Mon', 'M1n') :     0 :  None :     1 : False :  True : Binary
#     ('G10', 'Mon', 'M2i') :     0 :  None :     1 : False :  True : Binary
#     ('G10', 'Mon', 'M2n') :     0 :  None :     1 : False :  True : Binary
#     ('G10', 'Mon', 'M3i') :     0 :  None :     1 : False :  True : Binary
#     ('G10', 'Mon', 'M3n') :     0 :  None :     1 : False :  True : Binary
#     ('G10', 'Sat', 'E1i') :     0 :  None :     1 : False :  True : Binary
#     ('G10', 'Sat', 'E1n') :     0 :  None :     1 : False :  True : Binary
#     ('G10', 'Sat', 'E2i') :     0 :  None :     1 : False :  True : Binary
#     ('G10', 'Sat', 'E2n') :     0 :  None :     1 : False :  True : Binary
#     ('G10', 'Sat', 'E3i') :     0 :  None :     1 : False :  True : Binary
#     ('G10', 'Sat', 'E3n') :     0 :  None :     1 : False :  True : Binary
#     ('G10', 'Sat', 'M1i') :     0 :  None :     1 : False :  True : Binary
#     ('G10', 'Sat', 'M1n') :     0 :  None :     1 : False :  True : Binary
#     ('G10', 'Sat', 'M2i') :     0 :  None :     1 : False :  True : Binary
#     ('G10', 'Sat', 'M2n') :     0 :  None :     1 : False :  True : Binary
#     ('G10', 'Sat', 'M3i') :     0 :  None :     1 : False :  True : Binary
#     ('G10', 'Sat', 'M3n') :     0 :  None :     1 : False :  True : Binary
#     ('G10', 'Sun', 'E1i') :     0 :  None :     1 : False :  True : Binary
#     ('G10', 'Sun', 'E1n') :     0 :  None :     1 : False :  True : Binary
#     ('G10', 'Sun', 'E2i') :     0 :  None :     1 : False :  True : Binary
#     ('G10', 'Sun', 'E2n') :     0 :  None :     1 : False :  True : Binary
#     ('G10', 'Sun', 'E3i') :     0 :  None :     1 : False :  True : Binary
#     ('G10', 'Sun', 'E3n') :     0 :  None :     1 : False :  True : Binary
#     ('G10', 'Sun', 'M1i') :     0 :  None :     1 : False :  True : Binary
#     ('G10', 'Sun', 'M1n') :     0 :  None :     1 : False :  True : Binary
#     ('G10', 'Sun', 'M2i') :     0 :  None :     1 : False :  True : Binary
#     ('G10', 'Sun', 'M2n') :     0 :  None :     1 : False :  True : Binary
#     ('G10', 'Sun', 'M3i') :     0 :  None :     1 : False :  True : Binary
#     ('G10', 'Sun', 'M3n') :     0 :  None :     1 : False :  True : Binary
#     ('G10', 'Thu', 'E1i') :     0 :  None :     1 : False :  True : Binary
#     ('G10', 'Thu', 'E1n') :     0 :  None :     1 : False :  True : Binary
#     ('G10', 'Thu', 'E2i') :     0 :  None :     1 : False :  True : Binary
#     ('G10', 'Thu', 'E2n') :     0 :  None :     1 : False :  True : Binary
#     ('G10', 'Thu', 'E3i') :     0 :  None :     1 : False :  True : Binary
#     ('G10', 'Thu', 'E3n') :     0 :  None :     1 : False :  True : Binary
#     ('G10', 'Thu', 'M1i') :     0 :  None :     1 : False :  True : Binary
#     ('G10', 'Thu', 'M1n') :     0 :  None :     1 : False :  True : Binary
#     ('G10', 'Thu', 'M2i') :     0 :  None :     1 : False :  True : Binary
#     ('G10', 'Thu', 'M2n') :     0 :  None :     1 : False :  True : Binary
#     ('G10', 'Thu', 'M3i') :     0 :  None :     1 : False :  True : Binary
#     ('G10', 'Thu', 'M3n') :     0 :  None :     1 : False :  True : Binary
#     ('G10', 'Tue', 'E1i') :     0 :  None :     1 : False :  True : Binary
#     ('G10', 'Tue', 'E1n') :     0 :  None :     1 : False :  True : Binary
#     ('G10', 'Tue', 'E2i') :     0 :  None :     1 : False :  True : Binary
#     ('G10', 'Tue', 'E2n') :     0 :  None :     1 : False :  True : Binary
#     ('G10', 'Tue', 'E3i') :     0 :  None :     1 : False :  True : Binary
#     ('G10', 'Tue', 'E3n') :     0 :  None :     1 : False :  True : Binary
#     ('G10', 'Tue', 'M1i') :     0 :  None :     1 : False :  True : Binary
#     ('G10', 'Tue', 'M1n') :     0 :  None :     1 : False :  True : Binary
#     ('G10', 'Tue', 'M2i') :     0 :  None :     1 : False :  True : Binary
#     ('G10', 'Tue', 'M2n') :     0 :  None :     1 : False :  True : Binary
#     ('G10', 'Tue', 'M3i') :     0 :  None :     1 : False :  True : Binary
#     ('G10', 'Tue', 'M3n') :     0 :  None :     1 : False :  True : Binary
#     ('G10', 'Wed', 'E1i') :     0 :  None :     1 : False :  True : Binary
#     ('G10', 'Wed', 'E1n') :     0 :  None :     1 : False :  True : Binary
#     ('G10', 'Wed', 'E2i') :     0 :  None :     1 : False :  True : Binary
#     ('G10', 'Wed', 'E2n') :     0 :  None :     1 : False :  True : Binary
#     ('G10', 'Wed', 'E3i') :     0 :  None :     1 : False :  True : Binary
#     ('G10', 'Wed', 'E3n') :     0 :  None :     1 : False :  True : Binary
#     ('G10', 'Wed', 'M1i') :     0 :  None :     1 : False :  True : Binary
#     ('G10', 'Wed', 'M1n') :     0 :  None :     1 : False :  True : Binary
#     ('G10', 'Wed', 'M2i') :     0 :  None :     1 : False :  True : Binary
#     ('G10', 'Wed', 'M2n') :     0 :  None :     1 : False :  True : Binary
#     ('G10', 'Wed', 'M3i') :     0 :  None :     1 : False :  True : Binary
#     ('G10', 'Wed', 'M3n') :     0 :  None :     1 : False :  True : Binary
#     ('G11', 'Fri', 'E1i') :     0 :  None :     1 : False :  True : Binary
#     ('G11', 'Fri', 'E1n') :     0 :  None :     1 : False :  True : Binary
#     ('G11', 'Fri', 'E2i') :     0 :  None :     1 : False :  True : Binary
#     ('G11', 'Fri', 'E2n') :     0 :  None :     1 : False :  True : Binary
#     ('G11', 'Fri', 'E3i') :     0 :  None :     1 : False :  True : Binary
#     ('G11', 'Fri', 'E3n') :     0 :  None :     1 : False :  True : Binary
#     ('G11', 'Fri', 'M1i') :     0 :  None :     1 : False :  True : Binary
#     ('G11', 'Fri', 'M1n') :     0 :  None :     1 : False :  True : Binary
#     ('G11', 'Fri', 'M2i') :     0 :  None :     1 : False :  True : Binary
#     ('G11', 'Fri', 'M2n') :     0 :  None :     1 : False :  True : Binary
#     ('G11', 'Fri', 'M3i') :     0 :  None :     1 : False :  True : Binary
#     ('G11', 'Fri', 'M3n') :     0 :  None :     1 : False :  True : Binary
#     ('G11', 'Mon', 'E1i') :     0 :  None :     1 : False :  True : Binary
#     ('G11', 'Mon', 'E1n') :     0 :  None :     1 : False :  True : Binary
#     ('G11', 'Mon', 'E2i') :     0 :  None :     1 : False :  True : Binary
#     ('G11', 'Mon', 'E2n') :     0 :  None :     1 : False :  True : Binary
#     ('G11', 'Mon', 'E3i') :     0 :  None :     1 : False :  True : Binary
#     ('G11', 'Mon', 'E3n') :     0 :  None :     1 : False :  True : Binary
#     ('G11', 'Mon', 'M1i') :     0 :  None :     1 : False :  True : Binary
#     ('G11', 'Mon', 'M1n') :     0 :  None :     1 : False :  True : Binary
#     ('G11', 'Mon', 'M2i') :     0 :  None :     1 : False :  True : Binary
#     ('G11', 'Mon', 'M2n') :     0 :  None :     1 : False :  True : Binary
#     ('G11', 'Mon', 'M3i') :     0 :  None :     1 : False :  True : Binary
#     ('G11', 'Mon', 'M3n') :     0 :  None :     1 : False :  True : Binary
#     ('G11', 'Sat', 'E1i') :     0 :  None :     1 : False :  True : Binary
#     ('G11', 'Sat', 'E1n') :     0 :  None :     1 : False :  True : Binary
#     ('G11', 'Sat', 'E2i') :     0 :  None :     1 : False :  True : Binary
#     ('G11', 'Sat', 'E2n') :     0 :  None :     1 : False :  True : Binary
#     ('G11', 'Sat', 'E3i') :     0 :  None :     1 : False :  True : Binary
#     ('G11', 'Sat', 'E3n') :     0 :  None :     1 : False :  True : Binary
#     ('G11', 'Sat', 'M1i') :     0 :  None :     1 : False :  True : Binary
#     ('G11', 'Sat', 'M1n') :     0 :  None :     1 : False :  True : Binary
#     ('G11', 'Sat', 'M2i') :     0 :  None :     1 : False :  True : Binary
#     ('G11', 'Sat', 'M2n') :     0 :  None :     1 : False :  True : Binary
#     ('G11', 'Sat', 'M3i') :     0 :  None :     1 : False :  True : Binary
#     ('G11', 'Sat', 'M3n') :     0 :  None :     1 : False :  True : Binary
#     ('G11', 'Sun', 'E1i') :     0 :  None :     1 : False :  True : Binary
#     ('G11', 'Sun', 'E1n') :     0 :  None :     1 : False :  True : Binary
#     ('G11', 'Sun', 'E2i') :     0 :  None :     1 : False :  True : Binary
#     ('G11', 'Sun', 'E2n') :     0 :  None :     1 : False :  True : Binary
#     ('G11', 'Sun', 'E3i') :     0 :  None :     1 : False :  True : Binary
#     ('G11', 'Sun', 'E3n') :     0 :  None :     1 : False :  True : Binary
#     ('G11', 'Sun', 'M1i') :     0 :  None :     1 : False :  True : Binary
#     ('G11', 'Sun', 'M1n') :     0 :  None :     1 : False :  True : Binary
#     ('G11', 'Sun', 'M2i') :     0 :  None :     1 : False :  True : Binary
#     ('G11', 'Sun', 'M2n') :     0 :  None :     1 : False :  True : Binary
#     ('G11', 'Sun', 'M3i') :     0 :  None :     1 : False :  True : Binary
#     ('G11', 'Sun', 'M3n') :     0 :  None :     1 : False :  True : Binary
#     ('G11', 'Thu', 'E1i') :     0 :  None :     1 : False :  True : Binary
#     ('G11', 'Thu', 'E1n') :     0 :  None :     1 : False :  True : Binary
#     ('G11', 'Thu', 'E2i') :     0 :  None :     1 : False :  True : Binary
#     ('G11', 'Thu', 'E2n') :     0 :  None :     1 : False :  True : Binary
#     ('G11', 'Thu', 'E3i') :     0 :  None :     1 : False :  True : Binary
#     ('G11', 'Thu', 'E3n') :     0 :  None :     1 : False :  True : Binary
#     ('G11', 'Thu', 'M1i') :     0 :  None :     1 : False :  True : Binary
#     ('G11', 'Thu', 'M1n') :     0 :  None :     1 : False :  True : Binary
#     ('G11', 'Thu', 'M2i') :     0 :  None :     1 : False :  True : Binary
#     ('G11', 'Thu', 'M2n') :     0 :  None :     1 : False :  True : Binary
#     ('G11', 'Thu', 'M3i') :     0 :  None :     1 : False :  True : Binary
#     ('G11', 'Thu', 'M3n') :     0 :  None :     1 : False :  True : Binary
#     ('G11', 'Tue', 'E1i') :     0 :  None :     1 : False :  True : Binary
#     ('G11', 'Tue', 'E1n') :     0 :  None :     1 : False :  True : Binary
#     ('G11', 'Tue', 'E2i') :     0 :  None :     1 : False :  True : Binary
#     ('G11', 'Tue', 'E2n') :     0 :  None :     1 : False :  True : Binary
#     ('G11', 'Tue', 'E3i') :     0 :  None :     1 : False :  True : Binary
#     ('G11', 'Tue', 'E3n') :     0 :  None :     1 : False :  True : Binary
#     ('G11', 'Tue', 'M1i') :     0 :  None :     1 : False :  True : Binary
#     ('G11', 'Tue', 'M1n') :     0 :  None :     1 : False :  True : Binary
#     ('G11', 'Tue', 'M2i') :     0 :  None :     1 : False :  True : Binary
#     ('G11', 'Tue', 'M2n') :     0 :  None :     1 : False :  True : Binary
#     ('G11', 'Tue', 'M3i') :     0 :  None :     1 : False :  True : Binary
#     ('G11', 'Tue', 'M3n') :     0 :  None :     1 : False :  True : Binary
#     ('G11', 'Wed', 'E1i') :     0 :  None :     1 : False :  True : Binary
#     ('G11', 'Wed', 'E1n') :     0 :  None :     1 : False :  True : Binary
#     ('G11', 'Wed', 'E2i') :     0 :  None :     1 : False :  True : Binary
#     ('G11', 'Wed', 'E2n') :     0 :  None :     1 : False :  True : Binary
#     ('G11', 'Wed', 'E3i') :     0 :  None :     1 : False :  True : Binary
#     ('G11', 'Wed', 'E3n') :     0 :  None :     1 : False :  True : Binary
#     ('G11', 'Wed', 'M1i') :     0 :  None :     1 : False :  True : Binary
#     ('G11', 'Wed', 'M1n') :     0 :  None :     1 : False :  True : Binary
#     ('G11', 'Wed', 'M2i') :     0 :  None :     1 : False :  True : Binary
#     ('G11', 'Wed', 'M2n') :     0 :  None :     1 : False :  True : Binary
#     ('G11', 'Wed', 'M3i') :     0 :  None :     1 : False :  True : Binary
#     ('G11', 'Wed', 'M3n') :     0 :  None :     1 : False :  True : Binary
#     ('G12', 'Fri', 'E1i') :     0 :  None :     1 : False :  True : Binary
#     ('G12', 'Fri', 'E1n') :     0 :  None :     1 : False :  True : Binary
#     ('G12', 'Fri', 'E2i') :     0 :  None :     1 : False :  True : Binary
#     ('G12', 'Fri', 'E2n') :     0 :  None :     1 : False :  True : Binary
#     ('G12', 'Fri', 'E3i') :     0 :  None :     1 : False :  True : Binary
#     ('G12', 'Fri', 'E3n') :     0 :  None :     1 : False :  True : Binary
#     ('G12', 'Fri', 'M1i') :     0 :  None :     1 : False :  True : Binary
#     ('G12', 'Fri', 'M1n') :     0 :  None :     1 : False :  True : Binary
#     ('G12', 'Fri', 'M2i') :     0 :  None :     1 : False :  True : Binary
#     ('G12', 'Fri', 'M2n') :     0 :  None :     1 : False :  True : Binary
#     ('G12', 'Fri', 'M3i') :     0 :  None :     1 : False :  True : Binary
#     ('G12', 'Fri', 'M3n') :     0 :  None :     1 : False :  True : Binary
#     ('G12', 'Mon', 'E1i') :     0 :  None :     1 : False :  True : Binary
#     ('G12', 'Mon', 'E1n') :     0 :  None :     1 : False :  True : Binary
#     ('G12', 'Mon', 'E2i') :     0 :  None :     1 : False :  True : Binary
#     ('G12', 'Mon', 'E2n') :     0 :  None :     1 : False :  True : Binary
#     ('G12', 'Mon', 'E3i') :     0 :  None :     1 : False :  True : Binary
#     ('G12', 'Mon', 'E3n') :     0 :  None :     1 : False :  True : Binary
#     ('G12', 'Mon', 'M1i') :     0 :  None :     1 : False :  True : Binary
#     ('G12', 'Mon', 'M1n') :     0 :  None :     1 : False :  True : Binary
#     ('G12', 'Mon', 'M2i') :     0 :  None :     1 : False :  True : Binary
#     ('G12', 'Mon', 'M2n') :     0 :  None :     1 : False :  True : Binary
#     ('G12', 'Mon', 'M3i') :     0 :  None :     1 : False :  True : Binary
#     ('G12', 'Mon', 'M3n') :     0 :  None :     1 : False :  True : Binary
#     ('G12', 'Sat', 'E1i') :     0 :  None :     1 : False :  True : Binary
#     ('G12', 'Sat', 'E1n') :     0 :  None :     1 : False :  True : Binary
#     ('G12', 'Sat', 'E2i') :     0 :  None :     1 : False :  True : Binary
#     ('G12', 'Sat', 'E2n') :     0 :  None :     1 : False :  True : Binary
#     ('G12', 'Sat', 'E3i') :     0 :  None :     1 : False :  True : Binary
#     ('G12', 'Sat', 'E3n') :     0 :  None :     1 : False :  True : Binary
#     ('G12', 'Sat', 'M1i') :     0 :  None :     1 : False :  True : Binary
#     ('G12', 'Sat', 'M1n') :     0 :  None :     1 : False :  True : Binary
#     ('G12', 'Sat', 'M2i') :     0 :  None :     1 : False :  True : Binary
#     ('G12', 'Sat', 'M2n') :     0 :  None :     1 : False :  True : Binary
#     ('G12', 'Sat', 'M3i') :     0 :  None :     1 : False :  True : Binary
#     ('G12', 'Sat', 'M3n') :     0 :  None :     1 : False :  True : Binary
#     ('G12', 'Sun', 'E1i') :     0 :  None :     1 : False :  True : Binary
#     ('G12', 'Sun', 'E1n') :     0 :  None :     1 : False :  True : Binary
#     ('G12', 'Sun', 'E2i') :     0 :  None :     1 : False :  True : Binary
#     ('G12', 'Sun', 'E2n') :     0 :  None :     1 : False :  True : Binary
#     ('G12', 'Sun', 'E3i') :     0 :  None :     1 : False :  True : Binary
#     ('G12', 'Sun', 'E3n') :     0 :  None :     1 : False :  True : Binary
#     ('G12', 'Sun', 'M1i') :     0 :  None :     1 : False :  True : Binary
#     ('G12', 'Sun', 'M1n') :     0 :  None :     1 : False :  True : Binary
#     ('G12', 'Sun', 'M2i') :     0 :  None :     1 : False :  True : Binary
#     ('G12', 'Sun', 'M2n') :     0 :  None :     1 : False :  True : Binary
#     ('G12', 'Sun', 'M3i') :     0 :  None :     1 : False :  True : Binary
#     ('G12', 'Sun', 'M3n') :     0 :  None :     1 : False :  True : Binary
#     ('G12', 'Thu', 'E1i') :     0 :  None :     1 : False :  True : Binary
#     ('G12', 'Thu', 'E1n') :     0 :  None :     1 : False :  True : Binary
#     ('G12', 'Thu', 'E2i') :     0 :  None :     1 : False :  True : Binary
#     ('G12', 'Thu', 'E2n') :     0 :  None :     1 : False :  True : Binary
#     ('G12', 'Thu', 'E3i') :     0 :  None :     1 : False :  True : Binary
#     ('G12', 'Thu', 'E3n') :     0 :  None :     1 : False :  True : Binary
#     ('G12', 'Thu', 'M1i') :     0 :  None :     1 : False :  True : Binary
#     ('G12', 'Thu', 'M1n') :     0 :  None :     1 : False :  True : Binary
#     ('G12', 'Thu', 'M2i') :     0 :  None :     1 : False :  True : Binary
#     ('G12', 'Thu', 'M2n') :     0 :  None :     1 : False :  True : Binary
#     ('G12', 'Thu', 'M3i') :     0 :  None :     1 : False :  True : Binary
#     ('G12', 'Thu', 'M3n') :     0 :  None :     1 : False :  True : Binary
#     ('G12', 'Tue', 'E1i') :     0 :  None :     1 : False :  True : Binary
#     ('G12', 'Tue', 'E1n') :     0 :  None :     1 : False :  True : Binary
#     ('G12', 'Tue', 'E2i') :     0 :  None :     1 : False :  True : Binary
#     ('G12', 'Tue', 'E2n') :     0 :  None :     1 : False :  True : Binary
#     ('G12', 'Tue', 'E3i') :     0 :  None :     1 : False :  True : Binary
#     ('G12', 'Tue', 'E3n') :     0 :  None :     1 : False :  True : Binary
#     ('G12', 'Tue', 'M1i') :     0 :  None :     1 : False :  True : Binary
#     ('G12', 'Tue', 'M1n') :     0 :  None :     1 : False :  True : Binary
#     ('G12', 'Tue', 'M2i') :     0 :  None :     1 : False :  True : Binary
#     ('G12', 'Tue', 'M2n') :     0 :  None :     1 : False :  True : Binary
#     ('G12', 'Tue', 'M3i') :     0 :  None :     1 : False :  True : Binary
#     ('G12', 'Tue', 'M3n') :     0 :  None :     1 : False :  True : Binary
#     ('G12', 'Wed', 'E1i') :     0 :  None :     1 : False :  True : Binary
#     ('G12', 'Wed', 'E1n') :     0 :  None :     1 : False :  True : Binary
#     ('G12', 'Wed', 'E2i') :     0 :  None :     1 : False :  True : Binary
#     ('G12', 'Wed', 'E2n') :     0 :  None :     1 : False :  True : Binary
#     ('G12', 'Wed', 'E3i') :     0 :  None :     1 : False :  True : Binary
#     ('G12', 'Wed', 'E3n') :     0 :  None :     1 : False :  True : Binary
#     ('G12', 'Wed', 'M1i') :     0 :  None :     1 : False :  True : Binary
#     ('G12', 'Wed', 'M1n') :     0 :  None :     1 : False :  True : Binary
#     ('G12', 'Wed', 'M2i') :     0 :  None :     1 : False :  True : Binary
#     ('G12', 'Wed', 'M2n') :     0 :  None :     1 : False :  True : Binary
#     ('G12', 'Wed', 'M3i') :     0 :  None :     1 : False :  True : Binary
#     ('G12', 'Wed', 'M3n') :     0 :  None :     1 : False :  True : Binary
#     ('G13', 'Fri', 'E1i') :     0 :  None :     1 : False :  True : Binary
#     ('G13', 'Fri', 'E1n') :     0 :  None :     1 : False :  True : Binary
#     ('G13', 'Fri', 'E2i') :     0 :  None :     1 : False :  True : Binary
#     ('G13', 'Fri', 'E2n') :     0 :  None :     1 : False :  True : Binary
#     ('G13', 'Fri', 'E3i') :     0 :  None :     1 : False :  True : Binary
#     ('G13', 'Fri', 'E3n') :     0 :  None :     1 : False :  True : Binary
#     ('G13', 'Fri', 'M1i') :     0 :  None :     1 : False :  True : Binary
#     ('G13', 'Fri', 'M1n') :     0 :  None :     1 : False :  True : Binary
#     ('G13', 'Fri', 'M2i') :     0 :  None :     1 : False :  True : Binary
#     ('G13', 'Fri', 'M2n') :     0 :  None :     1 : False :  True : Binary
#     ('G13', 'Fri', 'M3i') :     0 :  None :     1 : False :  True : Binary
#     ('G13', 'Fri', 'M3n') :     0 :  None :     1 : False :  True : Binary
#     ('G13', 'Mon', 'E1i') :     0 :  None :     1 : False :  True : Binary
#     ('G13', 'Mon', 'E1n') :     0 :  None :     1 : False :  True : Binary
#     ('G13', 'Mon', 'E2i') :     0 :  None :     1 : False :  True : Binary
#     ('G13', 'Mon', 'E2n') :     0 :  None :     1 : False :  True : Binary
#     ('G13', 'Mon', 'E3i') :     0 :  None :     1 : False :  True : Binary
#     ('G13', 'Mon', 'E3n') :     0 :  None :     1 : False :  True : Binary
#     ('G13', 'Mon', 'M1i') :     0 :  None :     1 : False :  True : Binary
#     ('G13', 'Mon', 'M1n') :     0 :  None :     1 : False :  True : Binary
#     ('G13', 'Mon', 'M2i') :     0 :  None :     1 : False :  True : Binary
#     ('G13', 'Mon', 'M2n') :     0 :  None :     1 : False :  True : Binary
#     ('G13', 'Mon', 'M3i') :     0 :  None :     1 : False :  True : Binary
#     ('G13', 'Mon', 'M3n') :     0 :  None :     1 : False :  True : Binary
#     ('G13', 'Sat', 'E1i') :     0 :  None :     1 : False :  True : Binary
#     ('G13', 'Sat', 'E1n') :     0 :  None :     1 : False :  True : Binary
#     ('G13', 'Sat', 'E2i') :     0 :  None :     1 : False :  True : Binary
#     ('G13', 'Sat', 'E2n') :     0 :  None :     1 : False :  True : Binary
#     ('G13', 'Sat', 'E3i') :     0 :  None :     1 : False :  True : Binary
#     ('G13', 'Sat', 'E3n') :     0 :  None :     1 : False :  True : Binary
#     ('G13', 'Sat', 'M1i') :     0 :  None :     1 : False :  True : Binary
#     ('G13', 'Sat', 'M1n') :     0 :  None :     1 : False :  True : Binary
#     ('G13', 'Sat', 'M2i') :     0 :  None :     1 : False :  True : Binary
#     ('G13', 'Sat', 'M2n') :     0 :  None :     1 : False :  True : Binary
#     ('G13', 'Sat', 'M3i') :     0 :  None :     1 : False :  True : Binary
#     ('G13', 'Sat', 'M3n') :     0 :  None :     1 : False :  True : Binary
#     ('G13', 'Sun', 'E1i') :     0 :  None :     1 : False :  True : Binary
#     ('G13', 'Sun', 'E1n') :     0 :  None :     1 : False :  True : Binary
#     ('G13', 'Sun', 'E2i') :     0 :  None :     1 : False :  True : Binary
#     ('G13', 'Sun', 'E2n') :     0 :  None :     1 : False :  True : Binary
#     ('G13', 'Sun', 'E3i') :     0 :  None :     1 : False :  True : Binary
#     ('G13', 'Sun', 'E3n') :     0 :  None :     1 : False :  True : Binary
#     ('G13', 'Sun', 'M1i') :     0 :  None :     1 : False :  True : Binary
#     ('G13', 'Sun', 'M1n') :     0 :  None :     1 : False :  True : Binary
#     ('G13', 'Sun', 'M2i') :     0 :  None :     1 : False :  True : Binary
#     ('G13', 'Sun', 'M2n') :     0 :  None :     1 : False :  True : Binary
#     ('G13', 'Sun', 'M3i') :     0 :  None :     1 : False :  True : Binary
#     ('G13', 'Sun', 'M3n') :     0 :  None :     1 : False :  True : Binary
#     ('G13', 'Thu', 'E1i') :     0 :  None :     1 : False :  True : Binary
#     ('G13', 'Thu', 'E1n') :     0 :  None :     1 : False :  True : Binary
#     ('G13', 'Thu', 'E2i') :     0 :  None :     1 : False :  True : Binary
#     ('G13', 'Thu', 'E2n') :     0 :  None :     1 : False :  True : Binary
#     ('G13', 'Thu', 'E3i') :     0 :  None :     1 : False :  True : Binary
#     ('G13', 'Thu', 'E3n') :     0 :  None :     1 : False :  True : Binary
#     ('G13', 'Thu', 'M1i') :     0 :  None :     1 : False :  True : Binary
#     ('G13', 'Thu', 'M1n') :     0 :  None :     1 : False :  True : Binary
#     ('G13', 'Thu', 'M2i') :     0 :  None :     1 : False :  True : Binary
#     ('G13', 'Thu', 'M2n') :     0 :  None :     1 : False :  True : Binary
#     ('G13', 'Thu', 'M3i') :     0 :  None :     1 : False :  True : Binary
#     ('G13', 'Thu', 'M3n') :     0 :  None :     1 : False :  True : Binary
#     ('G13', 'Tue', 'E1i') :     0 :  None :     1 : False :  True : Binary
#     ('G13', 'Tue', 'E1n') :     0 :  None :     1 : False :  True : Binary
#     ('G13', 'Tue', 'E2i') :     0 :  None :     1 : False :  True : Binary
#     ('G13', 'Tue', 'E2n') :     0 :  None :     1 : False :  True : Binary
#     ('G13', 'Tue', 'E3i') :     0 :  None :     1 : False :  True : Binary
#     ('G13', 'Tue', 'E3n') :     0 :  None :     1 : False :  True : Binary
#     ('G13', 'Tue', 'M1i') :     0 :  None :     1 : False :  True : Binary
#     ('G13', 'Tue', 'M1n') :     0 :  None :     1 : False :  True : Binary
#     ('G13', 'Tue', 'M2i') :     0 :  None :     1 : False :  True : Binary
#     ('G13', 'Tue', 'M2n') :     0 :  None :     1 : False :  True : Binary
#     ('G13', 'Tue', 'M3i') :     0 :  None :     1 : False :  True : Binary
#     ('G13', 'Tue', 'M3n') :     0 :  None :     1 : False :  True : Binary
#     ('G13', 'Wed', 'E1i') :     0 :  None :     1 : False :  True : Binary
#     ('G13', 'Wed', 'E1n') :     0 :  None :     1 : False :  True : Binary
#     ('G13', 'Wed', 'E2i') :     0 :  None :     1 : False :  True : Binary
#     ('G13', 'Wed', 'E2n') :     0 :  None :     1 : False :  True : Binary
#     ('G13', 'Wed', 'E3i') :     0 :  None :     1 : False :  True : Binary
#     ('G13', 'Wed', 'E3n') :     0 :  None :     1 : False :  True : Binary
#     ('G13', 'Wed', 'M1i') :     0 :  None :     1 : False :  True : Binary
#     ('G13', 'Wed', 'M1n') :     0 :  None :     1 : False :  True : Binary
#     ('G13', 'Wed', 'M2i') :     0 :  None :     1 : False :  True : Binary
#     ('G13', 'Wed', 'M2n') :     0 :  None :     1 : False :  True : Binary
#     ('G13', 'Wed', 'M3i') :     0 :  None :     1 : False :  True : Binary
#     ('G13', 'Wed', 'M3n') :     0 :  None :     1 : False :  True : Binary
#     ('G14', 'Fri', 'E1i') :     0 :  None :     1 : False :  True : Binary
#     ('G14', 'Fri', 'E1n') :     0 :  None :     1 : False :  True : Binary
#     ('G14', 'Fri', 'E2i') :     0 :  None :     1 : False :  True : Binary
#     ('G14', 'Fri', 'E2n') :     0 :  None :     1 : False :  True : Binary
#     ('G14', 'Fri', 'E3i') :     0 :  None :     1 : False :  True : Binary
#     ('G14', 'Fri', 'E3n') :     0 :  None :     1 : False :  True : Binary
#     ('G14', 'Fri', 'M1i') :     0 :  None :     1 : False :  True : Binary
#     ('G14', 'Fri', 'M1n') :     0 :  None :     1 : False :  True : Binary
#     ('G14', 'Fri', 'M2i') :     0 :  None :     1 : False :  True : Binary
#     ('G14', 'Fri', 'M2n') :     0 :  None :     1 : False :  True : Binary
#     ('G14', 'Fri', 'M3i') :     0 :  None :     1 : False :  True : Binary
#     ('G14', 'Fri', 'M3n') :     0 :  None :     1 : False :  True : Binary
#     ('G14', 'Mon', 'E1i') :     0 :  None :     1 : False :  True : Binary
#     ('G14', 'Mon', 'E1n') :     0 :  None :     1 : False :  True : Binary
#     ('G14', 'Mon', 'E2i') :     0 :  None :     1 : False :  True : Binary
#     ('G14', 'Mon', 'E2n') :     0 :  None :     1 : False :  True : Binary
#     ('G14', 'Mon', 'E3i') :     0 :  None :     1 : False :  True : Binary
#     ('G14', 'Mon', 'E3n') :     0 :  None :     1 : False :  True : Binary
#     ('G14', 'Mon', 'M1i') :     0 :  None :     1 : False :  True : Binary
#     ('G14', 'Mon', 'M1n') :     0 :  None :     1 : False :  True : Binary
#     ('G14', 'Mon', 'M2i') :     0 :  None :     1 : False :  True : Binary
#     ('G14', 'Mon', 'M2n') :     0 :  None :     1 : False :  True : Binary
#     ('G14', 'Mon', 'M3i') :     0 :  None :     1 : False :  True : Binary
#     ('G14', 'Mon', 'M3n') :     0 :  None :     1 : False :  True : Binary
#     ('G14', 'Sat', 'E1i') :     0 :  None :     1 : False :  True : Binary
#     ('G14', 'Sat', 'E1n') :     0 :  None :     1 : False :  True : Binary
#     ('G14', 'Sat', 'E2i') :     0 :  None :     1 : False :  True : Binary
#     ('G14', 'Sat', 'E2n') :     0 :  None :     1 : False :  True : Binary
#     ('G14', 'Sat', 'E3i') :     0 :  None :     1 : False :  True : Binary
#     ('G14', 'Sat', 'E3n') :     0 :  None :     1 : False :  True : Binary
#     ('G14', 'Sat', 'M1i') :     0 :  None :     1 : False :  True : Binary
#     ('G14', 'Sat', 'M1n') :     0 :  None :     1 : False :  True : Binary
#     ('G14', 'Sat', 'M2i') :     0 :  None :     1 : False :  True : Binary
#     ('G14', 'Sat', 'M2n') :     0 :  None :     1 : False :  True : Binary
#     ('G14', 'Sat', 'M3i') :     0 :  None :     1 : False :  True : Binary
#     ('G14', 'Sat', 'M3n') :     0 :  None :     1 : False :  True : Binary
#     ('G14', 'Sun', 'E1i') :     0 :  None :     1 : False :  True : Binary
#     ('G14', 'Sun', 'E1n') :     0 :  None :     1 : False :  True : Binary
#     ('G14', 'Sun', 'E2i') :     0 :  None :     1 : False :  True : Binary
#     ('G14', 'Sun', 'E2n') :     0 :  None :     1 : False :  True : Binary
#     ('G14', 'Sun', 'E3i') :     0 :  None :     1 : False :  True : Binary
#     ('G14', 'Sun', 'E3n') :     0 :  None :     1 : False :  True : Binary
#     ('G14', 'Sun', 'M1i') :     0 :  None :     1 : False :  True : Binary
#     ('G14', 'Sun', 'M1n') :     0 :  None :     1 : False :  True : Binary
#     ('G14', 'Sun', 'M2i') :     0 :  None :     1 : False :  True : Binary
#     ('G14', 'Sun', 'M2n') :     0 :  None :     1 : False :  True : Binary
#     ('G14', 'Sun', 'M3i') :     0 :  None :     1 : False :  True : Binary
#     ('G14', 'Sun', 'M3n') :     0 :  None :     1 : False :  True : Binary
#     ('G14', 'Thu', 'E1i') :     0 :  None :     1 : False :  True : Binary
#     ('G14', 'Thu', 'E1n') :     0 :  None :     1 : False :  True : Binary
#     ('G14', 'Thu', 'E2i') :     0 :  None :     1 : False :  True : Binary
#     ('G14', 'Thu', 'E2n') :     0 :  None :     1 : False :  True : Binary
#     ('G14', 'Thu', 'E3i') :     0 :  None :     1 : False :  True : Binary
#     ('G14', 'Thu', 'E3n') :     0 :  None :     1 : False :  True : Binary
#     ('G14', 'Thu', 'M1i') :     0 :  None :     1 : False :  True : Binary
#     ('G14', 'Thu', 'M1n') :     0 :  None :     1 : False :  True : Binary
#     ('G14', 'Thu', 'M2i') :     0 :  None :     1 : False :  True : Binary
#     ('G14', 'Thu', 'M2n') :     0 :  None :     1 : False :  True : Binary
#     ('G14', 'Thu', 'M3i') :     0 :  None :     1 : False :  True : Binary
#     ('G14', 'Thu', 'M3n') :     0 :  None :     1 : False :  True : Binary
#     ('G14', 'Tue', 'E1i') :     0 :  None :     1 : False :  True : Binary
#     ('G14', 'Tue', 'E1n') :     0 :  None :     1 : False :  True : Binary
#     ('G14', 'Tue', 'E2i') :     0 :  None :     1 : False :  True : Binary
#     ('G14', 'Tue', 'E2n') :     0 :  None :     1 : False :  True : Binary
#     ('G14', 'Tue', 'E3i') :     0 :  None :     1 : False :  True : Binary
#     ('G14', 'Tue', 'E3n') :     0 :  None :     1 : False :  True : Binary
#     ('G14', 'Tue', 'M1i') :     0 :  None :     1 : False :  True : Binary
#     ('G14', 'Tue', 'M1n') :     0 :  None :     1 : False :  True : Binary
#     ('G14', 'Tue', 'M2i') :     0 :  None :     1 : False :  True : Binary
#     ('G14', 'Tue', 'M2n') :     0 :  None :     1 : False :  True : Binary
#     ('G14', 'Tue', 'M3i') :     0 :  None :     1 : False :  True : Binary
#     ('G14', 'Tue', 'M3n') :     0 :  None :     1 : False :  True : Binary
#     ('G14', 'Wed', 'E1i') :     0 :  None :     1 : False :  True : Binary
#     ('G14', 'Wed', 'E1n') :     0 :  None :     1 : False :  True : Binary
#     ('G14', 'Wed', 'E2i') :     0 :  None :     1 : False :  True : Binary
#     ('G14', 'Wed', 'E2n') :     0 :  None :     1 : False :  True : Binary
#     ('G14', 'Wed', 'E3i') :     0 :  None :     1 : False :  True : Binary
#     ('G14', 'Wed', 'E3n') :     0 :  None :     1 : False :  True : Binary
#     ('G14', 'Wed', 'M1i') :     0 :  None :     1 : False :  True : Binary
#     ('G14', 'Wed', 'M1n') :     0 :  None :     1 : False :  True : Binary
#     ('G14', 'Wed', 'M2i') :     0 :  None :     1 : False :  True : Binary
#     ('G14', 'Wed', 'M2n') :     0 :  None :     1 : False :  True : Binary
#     ('G14', 'Wed', 'M3i') :     0 :  None :     1 : False :  True : Binary
#     ('G14', 'Wed', 'M3n') :     0 :  None :     1 : False :  True : Binary
#     ('G15', 'Fri', 'E1i') :     0 :  None :     1 : False :  True : Binary
#     ('G15', 'Fri', 'E1n') :     0 :  None :     1 : False :  True : Binary
#     ('G15', 'Fri', 'E2i') :     0 :  None :     1 : False :  True : Binary
#     ('G15', 'Fri', 'E2n') :     0 :  None :     1 : False :  True : Binary
#     ('G15', 'Fri', 'E3i') :     0 :  None :     1 : False :  True : Binary
#     ('G15', 'Fri', 'E3n') :     0 :  None :     1 : False :  True : Binary
#     ('G15', 'Fri', 'M1i') :     0 :  None :     1 : False :  True : Binary
#     ('G15', 'Fri', 'M1n') :     0 :  None :     1 : False :  True : Binary
#     ('G15', 'Fri', 'M2i') :     0 :  None :     1 : False :  True : Binary
#     ('G15', 'Fri', 'M2n') :     0 :  None :     1 : False :  True : Binary
#     ('G15', 'Fri', 'M3i') :     0 :  None :     1 : False :  True : Binary
#     ('G15', 'Fri', 'M3n') :     0 :  None :     1 : False :  True : Binary
#     ('G15', 'Mon', 'E1i') :     0 :  None :     1 : False :  True : Binary
#     ('G15', 'Mon', 'E1n') :     0 :  None :     1 : False :  True : Binary
#     ('G15', 'Mon', 'E2i') :     0 :  None :     1 : False :  True : Binary
#     ('G15', 'Mon', 'E2n') :     0 :  None :     1 : False :  True : Binary
#     ('G15', 'Mon', 'E3i') :     0 :  None :     1 : False :  True : Binary
#     ('G15', 'Mon', 'E3n') :     0 :  None :     1 : False :  True : Binary
#     ('G15', 'Mon', 'M1i') :     0 :  None :     1 : False :  True : Binary
#     ('G15', 'Mon', 'M1n') :     0 :  None :     1 : False :  True : Binary
#     ('G15', 'Mon', 'M2i') :     0 :  None :     1 : False :  True : Binary
#     ('G15', 'Mon', 'M2n') :     0 :  None :     1 : False :  True : Binary
#     ('G15', 'Mon', 'M3i') :     0 :  None :     1 : False :  True : Binary
#     ('G15', 'Mon', 'M3n') :     0 :  None :     1 : False :  True : Binary
#     ('G15', 'Sat', 'E1i') :     0 :  None :     1 : False :  True : Binary
#     ('G15', 'Sat', 'E1n') :     0 :  None :     1 : False :  True : Binary
#     ('G15', 'Sat', 'E2i') :     0 :  None :     1 : False :  True : Binary
#     ('G15', 'Sat', 'E2n') :     0 :  None :     1 : False :  True : Binary
#     ('G15', 'Sat', 'E3i') :     0 :  None :     1 : False :  True : Binary
#     ('G15', 'Sat', 'E3n') :     0 :  None :     1 : False :  True : Binary
#     ('G15', 'Sat', 'M1i') :     0 :  None :     1 : False :  True : Binary
#     ('G15', 'Sat', 'M1n') :     0 :  None :     1 : False :  True : Binary
#     ('G15', 'Sat', 'M2i') :     0 :  None :     1 : False :  True : Binary
#     ('G15', 'Sat', 'M2n') :     0 :  None :     1 : False :  True : Binary
#     ('G15', 'Sat', 'M3i') :     0 :  None :     1 : False :  True : Binary
#     ('G15', 'Sat', 'M3n') :     0 :  None :     1 : False :  True : Binary
#     ('G15', 'Sun', 'E1i') :     0 :  None :     1 : False :  True : Binary
#     ('G15', 'Sun', 'E1n') :     0 :  None :     1 : False :  True : Binary
#     ('G15', 'Sun', 'E2i') :     0 :  None :     1 : False :  True : Binary
#     ('G15', 'Sun', 'E2n') :     0 :  None :     1 : False :  True : Binary
#     ('G15', 'Sun', 'E3i') :     0 :  None :     1 : False :  True : Binary
#     ('G15', 'Sun', 'E3n') :     0 :  None :     1 : False :  True : Binary
#     ('G15', 'Sun', 'M1i') :     0 :  None :     1 : False :  True : Binary
#     ('G15', 'Sun', 'M1n') :     0 :  None :     1 : False :  True : Binary
#     ('G15', 'Sun', 'M2i') :     0 :  None :     1 : False :  True : Binary
#     ('G15', 'Sun', 'M2n') :     0 :  None :     1 : False :  True : Binary
#     ('G15', 'Sun', 'M3i') :     0 :  None :     1 : False :  True : Binary
#     ('G15', 'Sun', 'M3n') :     0 :  None :     1 : False :  True : Binary
#     ('G15', 'Thu', 'E1i') :     0 :  None :     1 : False :  True : Binary
#     ('G15', 'Thu', 'E1n') :     0 :  None :     1 : False :  True : Binary
# ...
#      ('G7', 'Thu', 'E1i') :     0 :  None :     1 : False :  True : Binary
#      ('G7', 'Thu', 'E1n') :     0 :  None :     1 : False :  True : Binary
#      ('G7', 'Thu', 'E2i') :     0 :  None :     1 : False :  True : Binary
#      ('G7', 'Thu', 'E2n') :     0 :  None :     1 : False :  True : Binary
#      ('G7', 'Thu', 'E3i') :     0 :  None :     1 : False :  True : Binary
#      ('G7', 'Thu', 'E3n') :     0 :  None :     1 : False :  True : Binary
#      ('G7', 'Thu', 'M1i') :     0 :  None :     1 : False :  True : Binary
#      ('G7', 'Thu', 'M1n') :     0 :  None :     1 : False :  True : Binary
#      ('G7', 'Thu', 'M2i') :     0 :  None :     1 : False :  True : Binary
#      ('G7', 'Thu', 'M2n') :     0 :  None :     1 : False :  True : Binary
#      ('G7', 'Thu', 'M3i') :     0 :  None :     1 : False :  True : Binary
#      ('G7', 'Thu', 'M3n') :     0 :  None :     1 : False :  True : Binary
#      ('G7', 'Tue', 'E1i') :     0 :  None :     1 : False :  True : Binary
#      ('G7', 'Tue', 'E1n') :     0 :  None :     1 : False :  True : Binary
#      ('G7', 'Tue', 'E2i') :     0 :  None :     1 : False :  True : Binary
#      ('G7', 'Tue', 'E2n') :     0 :  None :     1 : False :  True : Binary
#      ('G7', 'Tue', 'E3i') :     0 :  None :     1 : False :  True : Binary
#      ('G7', 'Tue', 'E3n') :     0 :  None :     1 : False :  True : Binary
#      ('G7', 'Tue', 'M1i') :     0 :  None :     1 : False :  True : Binary
#      ('G7', 'Tue', 'M1n') :     0 :  None :     1 : False :  True : Binary
#      ('G7', 'Tue', 'M2i') :     0 :  None :     1 : False :  True : Binary
#      ('G7', 'Tue', 'M2n') :     0 :  None :     1 : False :  True : Binary
#      ('G7', 'Tue', 'M3i') :     0 :  None :     1 : False :  True : Binary
#      ('G7', 'Tue', 'M3n') :     0 :  None :     1 : False :  True : Binary
#      ('G7', 'Wed', 'E1i') :     0 :  None :     1 : False :  True : Binary
#      ('G7', 'Wed', 'E1n') :     0 :  None :     1 : False :  True : Binary
#      ('G7', 'Wed', 'E2i') :     0 :  None :     1 : False :  True : Binary
#      ('G7', 'Wed', 'E2n') :     0 :  None :     1 : False :  True : Binary
#      ('G7', 'Wed', 'E3i') :     0 :  None :     1 : False :  True : Binary
#      ('G7', 'Wed', 'E3n') :     0 :  None :     1 : False :  True : Binary
#      ('G7', 'Wed', 'M1i') :     0 :  None :     1 : False :  True : Binary
#      ('G7', 'Wed', 'M1n') :     0 :  None :     1 : False :  True : Binary
#      ('G7', 'Wed', 'M2i') :     0 :  None :     1 : False :  True : Binary
#      ('G7', 'Wed', 'M2n') :     0 :  None :     1 : False :  True : Binary
#      ('G7', 'Wed', 'M3i') :     0 :  None :     1 : False :  True : Binary
#      ('G7', 'Wed', 'M3n') :     0 :  None :     1 : False :  True : Binary
#      ('G8', 'Fri', 'E1i') :     0 :  None :     1 : False :  True : Binary
#      ('G8', 'Fri', 'E1n') :     0 :  None :     1 : False :  True : Binary
#      ('G8', 'Fri', 'E2i') :     0 :  None :     1 : False :  True : Binary
#      ('G8', 'Fri', 'E2n') :     0 :  None :     1 : False :  True : Binary
#      ('G8', 'Fri', 'E3i') :     0 :  None :     1 : False :  True : Binary
#      ('G8', 'Fri', 'E3n') :     0 :  None :     1 : False :  True : Binary
#      ('G8', 'Fri', 'M1i') :     0 :  None :     1 : False :  True : Binary
#      ('G8', 'Fri', 'M1n') :     0 :  None :     1 : False :  True : Binary
#      ('G8', 'Fri', 'M2i') :     0 :  None :     1 : False :  True : Binary
#      ('G8', 'Fri', 'M2n') :     0 :  None :     1 : False :  True : Binary
#      ('G8', 'Fri', 'M3i') :     0 :  None :     1 : False :  True : Binary
#      ('G8', 'Fri', 'M3n') :     0 :  None :     1 : False :  True : Binary
#      ('G8', 'Mon', 'E1i') :     0 :  None :     1 : False :  True : Binary
#      ('G8', 'Mon', 'E1n') :     0 :  None :     1 : False :  True : Binary
#      ('G8', 'Mon', 'E2i') :     0 :  None :     1 : False :  True : Binary
#      ('G8', 'Mon', 'E2n') :     0 :  None :     1 : False :  True : Binary
#      ('G8', 'Mon', 'E3i') :     0 :  None :     1 : False :  True : Binary
#      ('G8', 'Mon', 'E3n') :     0 :  None :     1 : False :  True : Binary
#      ('G8', 'Mon', 'M1i') :     0 :  None :     1 : False :  True : Binary
#      ('G8', 'Mon', 'M1n') :     0 :  None :     1 : False :  True : Binary
#      ('G8', 'Mon', 'M2i') :     0 :  None :     1 : False :  True : Binary
#      ('G8', 'Mon', 'M2n') :     0 :  None :     1 : False :  True : Binary
#      ('G8', 'Mon', 'M3i') :     0 :  None :     1 : False :  True : Binary
#      ('G8', 'Mon', 'M3n') :     0 :  None :     1 : False :  True : Binary
#      ('G8', 'Sat', 'E1i') :     0 :  None :     1 : False :  True : Binary
#      ('G8', 'Sat', 'E1n') :     0 :  None :     1 : False :  True : Binary
#      ('G8', 'Sat', 'E2i') :     0 :  None :     1 : False :  True : Binary
#      ('G8', 'Sat', 'E2n') :     0 :  None :     1 : False :  True : Binary
#      ('G8', 'Sat', 'E3i') :     0 :  None :     1 : False :  True : Binary
#      ('G8', 'Sat', 'E3n') :     0 :  None :     1 : False :  True : Binary
#      ('G8', 'Sat', 'M1i') :     0 :  None :     1 : False :  True : Binary
#      ('G8', 'Sat', 'M1n') :     0 :  None :     1 : False :  True : Binary
#      ('G8', 'Sat', 'M2i') :     0 :  None :     1 : False :  True : Binary
#      ('G8', 'Sat', 'M2n') :     0 :  None :     1 : False :  True : Binary
#      ('G8', 'Sat', 'M3i') :     0 :  None :     1 : False :  True : Binary
#      ('G8', 'Sat', 'M3n') :     0 :  None :     1 : False :  True : Binary
#      ('G8', 'Sun', 'E1i') :     0 :  None :     1 : False :  True : Binary
#      ('G8', 'Sun', 'E1n') :     0 :  None :     1 : False :  True : Binary
#      ('G8', 'Sun', 'E2i') :     0 :  None :     1 : False :  True : Binary
#      ('G8', 'Sun', 'E2n') :     0 :  None :     1 : False :  True : Binary
#      ('G8', 'Sun', 'E3i') :     0 :  None :     1 : False :  True : Binary
#      ('G8', 'Sun', 'E3n') :     0 :  None :     1 : False :  True : Binary
#      ('G8', 'Sun', 'M1i') :     0 :  None :     1 : False :  True : Binary
#      ('G8', 'Sun', 'M1n') :     0 :  None :     1 : False :  True : Binary
#      ('G8', 'Sun', 'M2i') :     0 :  None :     1 : False :  True : Binary
#      ('G8', 'Sun', 'M2n') :     0 :  None :     1 : False :  True : Binary
#      ('G8', 'Sun', 'M3i') :     0 :  None :     1 : False :  True : Binary
#      ('G8', 'Sun', 'M3n') :     0 :  None :     1 : False :  True : Binary
#      ('G8', 'Thu', 'E1i') :     0 :  None :     1 : False :  True : Binary
#      ('G8', 'Thu', 'E1n') :     0 :  None :     1 : False :  True : Binary
#      ('G8', 'Thu', 'E2i') :     0 :  None :     1 : False :  True : Binary
#      ('G8', 'Thu', 'E2n') :     0 :  None :     1 : False :  True : Binary
#      ('G8', 'Thu', 'E3i') :     0 :  None :     1 : False :  True : Binary
#      ('G8', 'Thu', 'E3n') :     0 :  None :     1 : False :  True : Binary
#      ('G8', 'Thu', 'M1i') :     0 :  None :     1 : False :  True : Binary
#      ('G8', 'Thu', 'M1n') :     0 :  None :     1 : False :  True : Binary
#      ('G8', 'Thu', 'M2i') :     0 :  None :     1 : False :  True : Binary
#      ('G8', 'Thu', 'M2n') :     0 :  None :     1 : False :  True : Binary
#      ('G8', 'Thu', 'M3i') :     0 :  None :     1 : False :  True : Binary
#      ('G8', 'Thu', 'M3n') :     0 :  None :     1 : False :  True : Binary
#      ('G8', 'Tue', 'E1i') :     0 :  None :     1 : False :  True : Binary
#      ('G8', 'Tue', 'E1n') :     0 :  None :     1 : False :  True : Binary
#      ('G8', 'Tue', 'E2i') :     0 :  None :     1 : False :  True : Binary
#      ('G8', 'Tue', 'E2n') :     0 :  None :     1 : False :  True : Binary
#      ('G8', 'Tue', 'E3i') :     0 :  None :     1 : False :  True : Binary
#      ('G8', 'Tue', 'E3n') :     0 :  None :     1 : False :  True : Binary
#      ('G8', 'Tue', 'M1i') :     0 :  None :     1 : False :  True : Binary
#      ('G8', 'Tue', 'M1n') :     0 :  None :     1 : False :  True : Binary
#      ('G8', 'Tue', 'M2i') :     0 :  None :     1 : False :  True : Binary
#      ('G8', 'Tue', 'M2n') :     0 :  None :     1 : False :  True : Binary
#      ('G8', 'Tue', 'M3i') :     0 :  None :     1 : False :  True : Binary
#      ('G8', 'Tue', 'M3n') :     0 :  None :     1 : False :  True : Binary
#      ('G8', 'Wed', 'E1i') :     0 :  None :     1 : False :  True : Binary
#      ('G8', 'Wed', 'E1n') :     0 :  None :     1 : False :  True : Binary
#      ('G8', 'Wed', 'E2i') :     0 :  None :     1 : False :  True : Binary
#      ('G8', 'Wed', 'E2n') :     0 :  None :     1 : False :  True : Binary
#      ('G8', 'Wed', 'E3i') :     0 :  None :     1 : False :  True : Binary
#      ('G8', 'Wed', 'E3n') :     0 :  None :     1 : False :  True : Binary
#      ('G8', 'Wed', 'M1i') :     0 :  None :     1 : False :  True : Binary
#      ('G8', 'Wed', 'M1n') :     0 :  None :     1 : False :  True : Binary
#      ('G8', 'Wed', 'M2i') :     0 :  None :     1 : False :  True : Binary
#      ('G8', 'Wed', 'M2n') :     0 :  None :     1 : False :  True : Binary
#      ('G8', 'Wed', 'M3i') :     0 :  None :     1 : False :  True : Binary
#      ('G8', 'Wed', 'M3n') :     0 :  None :     1 : False :  True : Binary
#      ('G9', 'Fri', 'E1i') :     0 :  None :     1 : False :  True : Binary
#      ('G9', 'Fri', 'E1n') :     0 :  None :     1 : False :  True : Binary
#      ('G9', 'Fri', 'E2i') :     0 :  None :     1 : False :  True : Binary
#      ('G9', 'Fri', 'E2n') :     0 :  None :     1 : False :  True : Binary
#      ('G9', 'Fri', 'E3i') :     0 :  None :     1 : False :  True : Binary
#      ('G9', 'Fri', 'E3n') :     0 :  None :     1 : False :  True : Binary
#      ('G9', 'Fri', 'M1i') :     0 :  None :     1 : False :  True : Binary
#      ('G9', 'Fri', 'M1n') :     0 :  None :     1 : False :  True : Binary
#      ('G9', 'Fri', 'M2i') :     0 :  None :     1 : False :  True : Binary
#      ('G9', 'Fri', 'M2n') :     0 :  None :     1 : False :  True : Binary
#      ('G9', 'Fri', 'M3i') :     0 :  None :     1 : False :  True : Binary
#      ('G9', 'Fri', 'M3n') :     0 :  None :     1 : False :  True : Binary
#      ('G9', 'Mon', 'E1i') :     0 :  None :     1 : False :  True : Binary
#      ('G9', 'Mon', 'E1n') :     0 :  None :     1 : False :  True : Binary
#      ('G9', 'Mon', 'E2i') :     0 :  None :     1 : False :  True : Binary
#      ('G9', 'Mon', 'E2n') :     0 :  None :     1 : False :  True : Binary
#      ('G9', 'Mon', 'E3i') :     0 :  None :     1 : False :  True : Binary
#      ('G9', 'Mon', 'E3n') :     0 :  None :     1 : False :  True : Binary
#      ('G9', 'Mon', 'M1i') :     0 :  None :     1 : False :  True : Binary
#      ('G9', 'Mon', 'M1n') :     0 :  None :     1 : False :  True : Binary
#      ('G9', 'Mon', 'M2i') :     0 :  None :     1 : False :  True : Binary
#      ('G9', 'Mon', 'M2n') :     0 :  None :     1 : False :  True : Binary
#      ('G9', 'Mon', 'M3i') :     0 :  None :     1 : False :  True : Binary
#      ('G9', 'Mon', 'M3n') :     0 :  None :     1 : False :  True : Binary
#      ('G9', 'Sat', 'E1i') :     0 :  None :     1 : False :  True : Binary
#      ('G9', 'Sat', 'E1n') :     0 :  None :     1 : False :  True : Binary
#      ('G9', 'Sat', 'E2i') :     0 :  None :     1 : False :  True : Binary
#      ('G9', 'Sat', 'E2n') :     0 :  None :     1 : False :  True : Binary
#      ('G9', 'Sat', 'E3i') :     0 :  None :     1 : False :  True : Binary
#      ('G9', 'Sat', 'E3n') :     0 :  None :     1 : False :  True : Binary
#      ('G9', 'Sat', 'M1i') :     0 :  None :     1 : False :  True : Binary
#      ('G9', 'Sat', 'M1n') :     0 :  None :     1 : False :  True : Binary
#      ('G9', 'Sat', 'M2i') :     0 :  None :     1 : False :  True : Binary
#      ('G9', 'Sat', 'M2n') :     0 :  None :     1 : False :  True : Binary
#      ('G9', 'Sat', 'M3i') :     0 :  None :     1 : False :  True : Binary
#      ('G9', 'Sat', 'M3n') :     0 :  None :     1 : False :  True : Binary
#      ('G9', 'Sun', 'E1i') :     0 :  None :     1 : False :  True : Binary
#      ('G9', 'Sun', 'E1n') :     0 :  None :     1 : False :  True : Binary
#      ('G9', 'Sun', 'E2i') :     0 :  None :     1 : False :  True : Binary
#      ('G9', 'Sun', 'E2n') :     0 :  None :     1 : False :  True : Binary
#      ('G9', 'Sun', 'E3i') :     0 :  None :     1 : False :  True : Binary
#      ('G9', 'Sun', 'E3n') :     0 :  None :     1 : False :  True : Binary
#      ('G9', 'Sun', 'M1i') :     0 :  None :     1 : False :  True : Binary
#      ('G9', 'Sun', 'M1n') :     0 :  None :     1 : False :  True : Binary
#      ('G9', 'Sun', 'M2i') :     0 :  None :     1 : False :  True : Binary
#      ('G9', 'Sun', 'M2n') :     0 :  None :     1 : False :  True : Binary
#      ('G9', 'Sun', 'M3i') :     0 :  None :     1 : False :  True : Binary
#      ('G9', 'Sun', 'M3n') :     0 :  None :     1 : False :  True : Binary
#      ('G9', 'Thu', 'E1i') :     0 :  None :     1 : False :  True : Binary
#      ('G9', 'Thu', 'E1n') :     0 :  None :     1 : False :  True : Binary
#      ('G9', 'Thu', 'E2i') :     0 :  None :     1 : False :  True : Binary
#      ('G9', 'Thu', 'E2n') :     0 :  None :     1 : False :  True : Binary
#      ('G9', 'Thu', 'E3i') :     0 :  None :     1 : False :  True : Binary
#      ('G9', 'Thu', 'E3n') :     0 :  None :     1 : False :  True : Binary
#      ('G9', 'Thu', 'M1i') :     0 :  None :     1 : False :  True : Binary
#      ('G9', 'Thu', 'M1n') :     0 :  None :     1 : False :  True : Binary
#      ('G9', 'Thu', 'M2i') :     0 :  None :     1 : False :  True : Binary
#      ('G9', 'Thu', 'M2n') :     0 :  None :     1 : False :  True : Binary
#      ('G9', 'Thu', 'M3i') :     0 :  None :     1 : False :  True : Binary
#      ('G9', 'Thu', 'M3n') :     0 :  None :     1 : False :  True : Binary
#      ('G9', 'Tue', 'E1i') :     0 :  None :     1 : False :  True : Binary
#      ('G9', 'Tue', 'E1n') :     0 :  None :     1 : False :  True : Binary
#      ('G9', 'Tue', 'E2i') :     0 :  None :     1 : False :  True : Binary
#      ('G9', 'Tue', 'E2n') :     0 :  None :     1 : False :  True : Binary
#      ('G9', 'Tue', 'E3i') :     0 :  None :     1 : False :  True : Binary
#      ('G9', 'Tue', 'E3n') :     0 :  None :     1 : False :  True : Binary
#      ('G9', 'Tue', 'M1i') :     0 :  None :     1 : False :  True : Binary
#      ('G9', 'Tue', 'M1n') :     0 :  None :     1 : False :  True : Binary
#      ('G9', 'Tue', 'M2i') :     0 :  None :     1 : False :  True : Binary
#      ('G9', 'Tue', 'M2n') :     0 :  None :     1 : False :  True : Binary
#      ('G9', 'Tue', 'M3i') :     0 :  None :     1 : False :  True : Binary
#      ('G9', 'Tue', 'M3n') :     0 :  None :     1 : False :  True : Binary
#      ('G9', 'Wed', 'E1i') :     0 :  None :     1 : False :  True : Binary
#      ('G9', 'Wed', 'E1n') :     0 :  None :     1 : False :  True : Binary
#      ('G9', 'Wed', 'E2i') :     0 :  None :     1 : False :  True : Binary
#      ('G9', 'Wed', 'E2n') :     0 :  None :     1 : False :  True : Binary
#      ('G9', 'Wed', 'E3i') :     0 :  None :     1 : False :  True : Binary
#      ('G9', 'Wed', 'E3n') :     0 :  None :     1 : False :  True : Binary
#      ('G9', 'Wed', 'M1i') :     0 :  None :     1 : False :  True : Binary
#      ('G9', 'Wed', 'M1n') :     0 :  None :     1 : False :  True : Binary
#      ('G9', 'Wed', 'M2i') :     0 :  None :     1 : False :  True : Binary
#      ('G9', 'Wed', 'M2n') :     0 :  None :     1 : False :  True : Binary
#      ('G9', 'Wed', 'M3i') :     0 :  None :     1 : False :  True : Binary
#      ('G9', 'Wed', 'M3n') :     0 :  None :     1 : False :  True : Binary
# None
# '\n# Other version\ndiscrete_model.x = pyo.Var(\n                                    ((physician, day, shift) for physician in i_labels for day in j_labels for shift in k_dict[day]),\n                                    within = pyo.Binary,\n                                    initialize = 0,\n                                    doc = "Present"\n                                    )\n\n# Print the variables x_ijk\n# that were created\nprint(discrete_model.x.display())\n\n# Check that the number of x_ijk variables\n# coincides with the theorical result\n# of 17 * 7 * 12 = 1428\nassert len(list(discrete_model.x.keys())) == NUMBER_OF_INTENSIVISTS * len(WEEK) * len(SHIFTS)\n'

# %% [markdown]
# #### 8.2 Define the objective function

# %%
# We define the optimal Intensivist to Patient ratios
# per scenario in accordance with the recommendations
# and instructions of the Spanish Ministry of Health
optimal_ratios = [
    1/10, 1/8, 1/4,
    1/10, 1/8, 1/12,
    1/10, 1/8, 1/4,
    1/10, 1/8, 1/12
    ]

# We check the optimal_ratios length
# to be 12 (one per scenario)
assert len(optimal_ratios) == 12

# %%
# This function executes the formula
# specified in the general formulation section
"""
def d_operations_rule(d_model: pyo.ConcreteModel) -> float:
    totalsum_1 = 0.0
    for count_j, j in enumerate(d_model.j):
        totalsum_2 = 0.0
        for count_k, k in enumerate(d_model.k):
            totalsum_3 = 0.0
            for count_i, i in enumerate(d_model.i):
                totalsum_3 += d_model.x[i,j,k]
                #print(f"{i=}")
                #print(f"{j=}")
                #print(f"{k=}")
                #print(f"{count_k=}")
            totalsum_2 = (totalsum_3 / d_model.patients[j,k] - optimal_ratios[count_k])
        totalsum_1 += totalsum_2
    return totalsum_1
"""


def d_operations_rule(d_model: pyo.ConcreteModel) -> float:
    sum_j = 0.0
    for j in d_model.j:
        sum_k = 0.0
        for count_k, k in enumerate(d_model.k):
            internal_sum = sum([d_model.x[i,j,k] for i in d_model.i])
            difference = (internal_sum / d_model.patients[j,k] - optimal_ratios[count_k])
            sum_k += difference
        sum_j += sum_k
    return sum_j

# We define the objective function to be used
# in this case it is employed as a wrapper
# for the d_operations_rule function
"""
def d_objective_rule(d_model: pyo.ConcreteModel) -> float:
    return d_operations_rule(d_model)
"""

def d_objective_rule(d_model: pyo.ConcreteModel) -> float:
    return sum([((sum([d_model.x[i,j,k] for i in d_model.i])/d_model.patients[j,k])-optimal_ratios[count_k]) for j in d_model.j for count_k, k in enumerate(d_model.k)])

# %%
# We instantiate the objective function for the model which is passed as a rule
# although Pyomo minimizes by default, we still explicitly specify this

discrete_model.objective = pyo.Objective(
                                            rule = d_objective_rule,
                                            sense = pyo.minimize,
                                            doc = "Real-to-Optimal Intensivist-to-Patient ratio"
                                            )

#discrete_model.objective.pprint()

# %% [markdown]
# #### 8.3 Define the constraints

# %%
# Function that establishes the constraint by which no doctor
# may work more than 48 hours per week, i.e., 4 shifts
def d_MaxWeeklyShifts(d_model: pyo.ConcreteModel, i: str) -> bool:
    return sum(d_model.x[i,j,k] for j in d_model.j for k in d_model.k) <= 4

# %%
# This constraint is now added to the model

discrete_model.maxWeeklyShifts = pyo.Constraint(
    discrete_model.i,
    rule = d_MaxWeeklyShifts,
    doc = "Maximum number of shifts per week per doctor"
)

#discrete_model.maxWeeklyShifts.pprint()

# %%
# Function that establishes the constraint by which the
# minimum rest period between two shifts is of 12 hours,
# i.e., one shift between two shifts
def d_MinRest(d_model: pyo.ConcreteModel, i: str, j: str) -> bool:
    return sum(d_model.x[i,j,k] for k in d_model.k) <= 1

# %%
# This constraint is now added to the model

discrete_model.minRest = pyo.Constraint(
    discrete_model.i,
    discrete_model.j,
    rule = d_MinRest,
    doc = "Minimum resting period between two shifts"
)

#discrete_model.minRest.pprint()

# %%
# Function that establishes that the presence of physicians
# is not prescribed for Level I during the weekend
def d_WeekendRulesFirstLevel(d_model: pyo.ConcreteModel, constraintList: pyo.ConstraintList) -> None:
    shift_list = ['M1i', 'E1i', 'M1n', 'E1n']
    for k in shift_list:
        for j in WEEKEND:
            for i in d_model.i:
                constraintList.add(expr = d_model.x[i,j,k] == 0)
    
    assert len(constraintList) == len(shift_list)*len(WEEKEND)*len(d_model.i) # 136
    constraintList.pprint()

    return

# Function that establishes that the presence of physicians
# is not prescribed for Level II during the weekend
# during the evening shift
def d_WeekendRulesSecondLevel(d_model: pyo.ConcreteModel, constraintList: pyo.ConstraintList) -> None:
    shift_list = ['E2i', 'E2n']
    for k in shift_list:
        for j in WEEKEND:
            for i in d_model.i:
                constraintList.add(expr = d_model.x[i,j,k] == 0)
    
    assert len(constraintList) == len(shift_list)*len(WEEKEND)*len(d_model.i) # 68
    #constraintList.pprint()

    return

# %%
# The medical staff constraints for Level I
# during the weekend are added to the model
discrete_model.weekendrules_firstlevel = pyo.ConstraintList()
d_WeekendRulesFirstLevel(discrete_model, discrete_model.weekendrules_firstlevel)

# The medical staff constraints for Level II
# during the weekend are added to the model
discrete_model.weekendrules_secondlevel = pyo.ConstraintList()
d_WeekendRulesSecondLevel(discrete_model, discrete_model.weekendrules_secondlevel)
# Out:
# weekendrules_firstlevel : Size=192, Index=weekendrules_firstlevel_index, Active=True
#     Key : Lower : Body           : Upper : Active
#       1 :   0.0 :  x[G0,Sat,M1i] :   0.0 :   True
#       2 :   0.0 :  x[G1,Sat,M1i] :   0.0 :   True
#       3 :   0.0 :  x[G2,Sat,M1i] :   0.0 :   True
#       4 :   0.0 :  x[G3,Sat,M1i] :   0.0 :   True
#       5 :   0.0 :  x[G4,Sat,M1i] :   0.0 :   True
#       6 :   0.0 :  x[G5,Sat,M1i] :   0.0 :   True
#       7 :   0.0 :  x[G6,Sat,M1i] :   0.0 :   True
#       8 :   0.0 :  x[G7,Sat,M1i] :   0.0 :   True
#       9 :   0.0 :  x[G8,Sat,M1i] :   0.0 :   True
#      10 :   0.0 :  x[G9,Sat,M1i] :   0.0 :   True
#      11 :   0.0 : x[G10,Sat,M1i] :   0.0 :   True
#      12 :   0.0 : x[G11,Sat,M1i] :   0.0 :   True
#      13 :   0.0 : x[G12,Sat,M1i] :   0.0 :   True
#      14 :   0.0 : x[G13,Sat,M1i] :   0.0 :   True
#      15 :   0.0 : x[G14,Sat,M1i] :   0.0 :   True
#      16 :   0.0 : x[G15,Sat,M1i] :   0.0 :   True
#      17 :   0.0 : x[G16,Sat,M1i] :   0.0 :   True
#      18 :   0.0 : x[G17,Sat,M1i] :   0.0 :   True
#      19 :   0.0 : x[G18,Sat,M1i] :   0.0 :   True
#      20 :   0.0 : x[G19,Sat,M1i] :   0.0 :   True
#      21 :   0.0 : x[G20,Sat,M1i] :   0.0 :   True
#      22 :   0.0 : x[G21,Sat,M1i] :   0.0 :   True
#      23 :   0.0 : x[G22,Sat,M1i] :   0.0 :   True
#      24 :   0.0 : x[G23,Sat,M1i] :   0.0 :   True
#      25 :   0.0 :  x[G0,Sun,M1i] :   0.0 :   True
#      26 :   0.0 :  x[G1,Sun,M1i] :   0.0 :   True
#      27 :   0.0 :  x[G2,Sun,M1i] :   0.0 :   True
#      28 :   0.0 :  x[G3,Sun,M1i] :   0.0 :   True
#      29 :   0.0 :  x[G4,Sun,M1i] :   0.0 :   True
#      30 :   0.0 :  x[G5,Sun,M1i] :   0.0 :   True
#      31 :   0.0 :  x[G6,Sun,M1i] :   0.0 :   True
#      32 :   0.0 :  x[G7,Sun,M1i] :   0.0 :   True
#      33 :   0.0 :  x[G8,Sun,M1i] :   0.0 :   True
#      34 :   0.0 :  x[G9,Sun,M1i] :   0.0 :   True
#      35 :   0.0 : x[G10,Sun,M1i] :   0.0 :   True
#      36 :   0.0 : x[G11,Sun,M1i] :   0.0 :   True
#      37 :   0.0 : x[G12,Sun,M1i] :   0.0 :   True
#      38 :   0.0 : x[G13,Sun,M1i] :   0.0 :   True
#      39 :   0.0 : x[G14,Sun,M1i] :   0.0 :   True
#      40 :   0.0 : x[G15,Sun,M1i] :   0.0 :   True
#      41 :   0.0 : x[G16,Sun,M1i] :   0.0 :   True
#      42 :   0.0 : x[G17,Sun,M1i] :   0.0 :   True
#      43 :   0.0 : x[G18,Sun,M1i] :   0.0 :   True
#      44 :   0.0 : x[G19,Sun,M1i] :   0.0 :   True
#      45 :   0.0 : x[G20,Sun,M1i] :   0.0 :   True
#      46 :   0.0 : x[G21,Sun,M1i] :   0.0 :   True
#      47 :   0.0 : x[G22,Sun,M1i] :   0.0 :   True
#      48 :   0.0 : x[G23,Sun,M1i] :   0.0 :   True
#      49 :   0.0 :  x[G0,Sat,E1i] :   0.0 :   True
#      50 :   0.0 :  x[G1,Sat,E1i] :   0.0 :   True
#      51 :   0.0 :  x[G2,Sat,E1i] :   0.0 :   True
#      52 :   0.0 :  x[G3,Sat,E1i] :   0.0 :   True
#      53 :   0.0 :  x[G4,Sat,E1i] :   0.0 :   True
#      54 :   0.0 :  x[G5,Sat,E1i] :   0.0 :   True
#      55 :   0.0 :  x[G6,Sat,E1i] :   0.0 :   True
#      56 :   0.0 :  x[G7,Sat,E1i] :   0.0 :   True
#      57 :   0.0 :  x[G8,Sat,E1i] :   0.0 :   True
#      58 :   0.0 :  x[G9,Sat,E1i] :   0.0 :   True
#      59 :   0.0 : x[G10,Sat,E1i] :   0.0 :   True
#      60 :   0.0 : x[G11,Sat,E1i] :   0.0 :   True
#      61 :   0.0 : x[G12,Sat,E1i] :   0.0 :   True
#      62 :   0.0 : x[G13,Sat,E1i] :   0.0 :   True
#      63 :   0.0 : x[G14,Sat,E1i] :   0.0 :   True
#      64 :   0.0 : x[G15,Sat,E1i] :   0.0 :   True
#      65 :   0.0 : x[G16,Sat,E1i] :   0.0 :   True
#      66 :   0.0 : x[G17,Sat,E1i] :   0.0 :   True
#      67 :   0.0 : x[G18,Sat,E1i] :   0.0 :   True
#      68 :   0.0 : x[G19,Sat,E1i] :   0.0 :   True
#      69 :   0.0 : x[G20,Sat,E1i] :   0.0 :   True
#      70 :   0.0 : x[G21,Sat,E1i] :   0.0 :   True
#      71 :   0.0 : x[G22,Sat,E1i] :   0.0 :   True
#      72 :   0.0 : x[G23,Sat,E1i] :   0.0 :   True
#      73 :   0.0 :  x[G0,Sun,E1i] :   0.0 :   True
#      74 :   0.0 :  x[G1,Sun,E1i] :   0.0 :   True
#      75 :   0.0 :  x[G2,Sun,E1i] :   0.0 :   True
#      76 :   0.0 :  x[G3,Sun,E1i] :   0.0 :   True
#      77 :   0.0 :  x[G4,Sun,E1i] :   0.0 :   True
#      78 :   0.0 :  x[G5,Sun,E1i] :   0.0 :   True
#      79 :   0.0 :  x[G6,Sun,E1i] :   0.0 :   True
#      80 :   0.0 :  x[G7,Sun,E1i] :   0.0 :   True
#      81 :   0.0 :  x[G8,Sun,E1i] :   0.0 :   True
#      82 :   0.0 :  x[G9,Sun,E1i] :   0.0 :   True
#      83 :   0.0 : x[G10,Sun,E1i] :   0.0 :   True
#      84 :   0.0 : x[G11,Sun,E1i] :   0.0 :   True
#      85 :   0.0 : x[G12,Sun,E1i] :   0.0 :   True
#      86 :   0.0 : x[G13,Sun,E1i] :   0.0 :   True
#      87 :   0.0 : x[G14,Sun,E1i] :   0.0 :   True
#      88 :   0.0 : x[G15,Sun,E1i] :   0.0 :   True
#      89 :   0.0 : x[G16,Sun,E1i] :   0.0 :   True
#      90 :   0.0 : x[G17,Sun,E1i] :   0.0 :   True
#      91 :   0.0 : x[G18,Sun,E1i] :   0.0 :   True
#      92 :   0.0 : x[G19,Sun,E1i] :   0.0 :   True
#      93 :   0.0 : x[G20,Sun,E1i] :   0.0 :   True
#      94 :   0.0 : x[G21,Sun,E1i] :   0.0 :   True
#      95 :   0.0 : x[G22,Sun,E1i] :   0.0 :   True
#      96 :   0.0 : x[G23,Sun,E1i] :   0.0 :   True
#      97 :   0.0 :  x[G0,Sat,M1n] :   0.0 :   True
#      98 :   0.0 :  x[G1,Sat,M1n] :   0.0 :   True
#      99 :   0.0 :  x[G2,Sat,M1n] :   0.0 :   True
#     100 :   0.0 :  x[G3,Sat,M1n] :   0.0 :   True
#     101 :   0.0 :  x[G4,Sat,M1n] :   0.0 :   True
#     102 :   0.0 :  x[G5,Sat,M1n] :   0.0 :   True
#     103 :   0.0 :  x[G6,Sat,M1n] :   0.0 :   True
#     104 :   0.0 :  x[G7,Sat,M1n] :   0.0 :   True
#     105 :   0.0 :  x[G8,Sat,M1n] :   0.0 :   True
#     106 :   0.0 :  x[G9,Sat,M1n] :   0.0 :   True
#     107 :   0.0 : x[G10,Sat,M1n] :   0.0 :   True
#     108 :   0.0 : x[G11,Sat,M1n] :   0.0 :   True
#     109 :   0.0 : x[G12,Sat,M1n] :   0.0 :   True
#     110 :   0.0 : x[G13,Sat,M1n] :   0.0 :   True
#     111 :   0.0 : x[G14,Sat,M1n] :   0.0 :   True
#     112 :   0.0 : x[G15,Sat,M1n] :   0.0 :   True
#     113 :   0.0 : x[G16,Sat,M1n] :   0.0 :   True
#     114 :   0.0 : x[G17,Sat,M1n] :   0.0 :   True
#     115 :   0.0 : x[G18,Sat,M1n] :   0.0 :   True
#     116 :   0.0 : x[G19,Sat,M1n] :   0.0 :   True
#     117 :   0.0 : x[G20,Sat,M1n] :   0.0 :   True
#     118 :   0.0 : x[G21,Sat,M1n] :   0.0 :   True
#     119 :   0.0 : x[G22,Sat,M1n] :   0.0 :   True
#     120 :   0.0 : x[G23,Sat,M1n] :   0.0 :   True
#     121 :   0.0 :  x[G0,Sun,M1n] :   0.0 :   True
#     122 :   0.0 :  x[G1,Sun,M1n] :   0.0 :   True
#     123 :   0.0 :  x[G2,Sun,M1n] :   0.0 :   True
#     124 :   0.0 :  x[G3,Sun,M1n] :   0.0 :   True
#     125 :   0.0 :  x[G4,Sun,M1n] :   0.0 :   True
#     126 :   0.0 :  x[G5,Sun,M1n] :   0.0 :   True
#     127 :   0.0 :  x[G6,Sun,M1n] :   0.0 :   True
#     128 :   0.0 :  x[G7,Sun,M1n] :   0.0 :   True
#     129 :   0.0 :  x[G8,Sun,M1n] :   0.0 :   True
#     130 :   0.0 :  x[G9,Sun,M1n] :   0.0 :   True
#     131 :   0.0 : x[G10,Sun,M1n] :   0.0 :   True
#     132 :   0.0 : x[G11,Sun,M1n] :   0.0 :   True
#     133 :   0.0 : x[G12,Sun,M1n] :   0.0 :   True
#     134 :   0.0 : x[G13,Sun,M1n] :   0.0 :   True
#     135 :   0.0 : x[G14,Sun,M1n] :   0.0 :   True
#     136 :   0.0 : x[G15,Sun,M1n] :   0.0 :   True
#     137 :   0.0 : x[G16,Sun,M1n] :   0.0 :   True
#     138 :   0.0 : x[G17,Sun,M1n] :   0.0 :   True
#     139 :   0.0 : x[G18,Sun,M1n] :   0.0 :   True
#     140 :   0.0 : x[G19,Sun,M1n] :   0.0 :   True
#     141 :   0.0 : x[G20,Sun,M1n] :   0.0 :   True
#     142 :   0.0 : x[G21,Sun,M1n] :   0.0 :   True
#     143 :   0.0 : x[G22,Sun,M1n] :   0.0 :   True
#     144 :   0.0 : x[G23,Sun,M1n] :   0.0 :   True
#     145 :   0.0 :  x[G0,Sat,E1n] :   0.0 :   True
#     146 :   0.0 :  x[G1,Sat,E1n] :   0.0 :   True
#     147 :   0.0 :  x[G2,Sat,E1n] :   0.0 :   True
#     148 :   0.0 :  x[G3,Sat,E1n] :   0.0 :   True
#     149 :   0.0 :  x[G4,Sat,E1n] :   0.0 :   True
#     150 :   0.0 :  x[G5,Sat,E1n] :   0.0 :   True
#     151 :   0.0 :  x[G6,Sat,E1n] :   0.0 :   True
#     152 :   0.0 :  x[G7,Sat,E1n] :   0.0 :   True
#     153 :   0.0 :  x[G8,Sat,E1n] :   0.0 :   True
#     154 :   0.0 :  x[G9,Sat,E1n] :   0.0 :   True
#     155 :   0.0 : x[G10,Sat,E1n] :   0.0 :   True
#     156 :   0.0 : x[G11,Sat,E1n] :   0.0 :   True
#     157 :   0.0 : x[G12,Sat,E1n] :   0.0 :   True
#     158 :   0.0 : x[G13,Sat,E1n] :   0.0 :   True
#     159 :   0.0 : x[G14,Sat,E1n] :   0.0 :   True
#     160 :   0.0 : x[G15,Sat,E1n] :   0.0 :   True
#     161 :   0.0 : x[G16,Sat,E1n] :   0.0 :   True
#     162 :   0.0 : x[G17,Sat,E1n] :   0.0 :   True
#     163 :   0.0 : x[G18,Sat,E1n] :   0.0 :   True
#     164 :   0.0 : x[G19,Sat,E1n] :   0.0 :   True
#     165 :   0.0 : x[G20,Sat,E1n] :   0.0 :   True
#     166 :   0.0 : x[G21,Sat,E1n] :   0.0 :   True
#     167 :   0.0 : x[G22,Sat,E1n] :   0.0 :   True
#     168 :   0.0 : x[G23,Sat,E1n] :   0.0 :   True
#     169 :   0.0 :  x[G0,Sun,E1n] :   0.0 :   True
#     170 :   0.0 :  x[G1,Sun,E1n] :   0.0 :   True
#     171 :   0.0 :  x[G2,Sun,E1n] :   0.0 :   True
#     172 :   0.0 :  x[G3,Sun,E1n] :   0.0 :   True
#     173 :   0.0 :  x[G4,Sun,E1n] :   0.0 :   True
#     174 :   0.0 :  x[G5,Sun,E1n] :   0.0 :   True
#     175 :   0.0 :  x[G6,Sun,E1n] :   0.0 :   True
#     176 :   0.0 :  x[G7,Sun,E1n] :   0.0 :   True
#     177 :   0.0 :  x[G8,Sun,E1n] :   0.0 :   True
#     178 :   0.0 :  x[G9,Sun,E1n] :   0.0 :   True
#     179 :   0.0 : x[G10,Sun,E1n] :   0.0 :   True
#     180 :   0.0 : x[G11,Sun,E1n] :   0.0 :   True
#     181 :   0.0 : x[G12,Sun,E1n] :   0.0 :   True
#     182 :   0.0 : x[G13,Sun,E1n] :   0.0 :   True
#     183 :   0.0 : x[G14,Sun,E1n] :   0.0 :   True
#     184 :   0.0 : x[G15,Sun,E1n] :   0.0 :   True
#     185 :   0.0 : x[G16,Sun,E1n] :   0.0 :   True
#     186 :   0.0 : x[G17,Sun,E1n] :   0.0 :   True
#     187 :   0.0 : x[G18,Sun,E1n] :   0.0 :   True
#     188 :   0.0 : x[G19,Sun,E1n] :   0.0 :   True
#     189 :   0.0 : x[G20,Sun,E1n] :   0.0 :   True
#     190 :   0.0 : x[G21,Sun,E1n] :   0.0 :   True
#     191 :   0.0 : x[G22,Sun,E1n] :   0.0 :   True
#     192 :   0.0 : x[G23,Sun,E1n] :   0.0 :   True

# %%
# Function that implements the minimal Intensivist-to-Patients ratio that
# is minimally admissible taking into account healthcare standards
# for Level I (which only requires physicians during weekdays)
def d_MinProportionFirstLevel(d_model: pyo.ConcreteModel, constraintList: pyo.ConstraintList) -> None:
    shift_list = ['M1i', 'E1i', 'M1n', 'E1n']
    for k in shift_list:
        for j in WEEKDAYS:
            constraintList.add(expr = (sum([d_model.x[i,j,k] for i in d_model.i])/d_model.patients[j,k] >= 1/14))
    
    assert len(constraintList) == len(shift_list)*len(WEEKDAYS) # 20
    #constraintList.pprint()

    return

# %%
# Function that implements the minimal Intensivist-to-Patients ratio  that
# is minimally admissible taking into account healthcare standards
# for Level II (which only requires physicians all week for the
# morning shift, but not for the evening one)
def d_MinProportionSecondLevel(d_model: pyo.ConcreteModel, constraintList: pyo.ConstraintList) -> None:

    # MORNING SHIFT
    morning_shift_list = ['M2i', 'M2n']
    for k in morning_shift_list:
        for j in WEEK:
            constraintList.add(expr = (sum([d_model.x[i,j,k] for i in d_model.i])/d_model.patients[j,k] >= 1/10))
    
    # EVENING SHIFT
    evening_shift_list = ['E2i', 'E2n']
    for k in evening_shift_list:
        for j in WEEKDAYS:
            constraintList.add(expr = (sum([d_model.x[i,j,k] for i in d_model.i])/d_model.patients[j,k] >= 1/10))

    assert len(constraintList) == (len(morning_shift_list)*len(WEEK) + len(evening_shift_list)*len(WEEKDAYS)) # 24
    #constraintList.pprint()

    return

# %%
# Function that implements the minimal Intensivist-to-Patients ratio that
# is minimally admissible taking into account healthcare standards
# for Level III (which requires physicians all week but at
# different ratios, in the morning shift at min. 1/6 and
# at the evening one at min. 1/12)
def d_MinProportionThirdLevel(d_model: pyo.ConcreteModel, constraintList: pyo.ConstraintList) -> None:

    # MORNING SHIFT
    morning_shift_list = ['M3i', 'M3n']
    for k in morning_shift_list:
        for j in WEEK:
            constraintList.add(expr = (sum([d_model.x[i,j,k] for i in d_model.i])/d_model.patients[j,k] >= 1/10000)) # 1/6
    
    # EVENING SHIFT
    evening_shift_list = ['E3i', 'E3n']
    for k in evening_shift_list:
        for j in WEEK:
            constraintList.add(expr = (sum([d_model.x[i,j,k] for i in d_model.i])/d_model.patients[j,k] >= 1/10000)) # 1/12

    assert len(constraintList) == (len(morning_shift_list)*len(WEEK) + len(evening_shift_list)*len(WEEK)) # 28
    #constraintList.pprint()

    return

# %%
# The minimal Intensivist-to-Patient constraints for 
# Level I are added to the model
discrete_model.minproportions_firstlevel = pyo.ConstraintList()
d_MinProportionFirstLevel(discrete_model, discrete_model.minproportions_firstlevel)

# %%
# The minimal Intensivist-to-Patient constraints for 
# Level II are added to the model
discrete_model.minproportions_secondlevel = pyo.ConstraintList()
d_MinProportionSecondLevel(discrete_model, discrete_model.minproportions_secondlevel)

# %%
# The minimal Intensivist-to-Patient constraints for 
# Level III are added to the model
discrete_model.minproportions_thirdlevel = pyo.ConstraintList()
d_MinProportionThirdLevel(discrete_model, discrete_model.minproportions_thirdlevel)

# %% [markdown]
# #### 8.4 Solve the linear programming problem

# %%
# Instantiate the linear programming algorithm implementation
# that is to be used, can be changed to
# Solver = SolverFactory('glpk'')
Solver = SolverFactory('gurobi')
#Solver.options['ResultFile'] = "test.ilp"
#discrete_model.iis = pyo.Suffix(direction=pyo.Suffix.IMPORT)
Solver.options['DualReductions'] = 0

# Solve the model using the solver
# Start the stopwatch
clock_start = process_time() 
Results = Solver.solve(discrete_model)
clock_stop = process_time()

# Display the Pyomo-[Gurobi/GLPK] solution
print("Elapsed time: ", clock_stop-clock_start) 
#discrete_model.x.display()
#display(discrete_model)
#discrete_model.x.display()
for k in discrete_model.x.keys():
    if abs(discrete_model.x[k].value) > 0:
        print(discrete_model.x[k].cname(), discrete_model.x[k].value)
#discrete_model.pprint()
#print("IIS Results")
#for component, value in discrete_model.iis.items():
#    print(component.name+" "+str(value))
# Out:
# Elapsed time:  0.109375
# WARNING: DEPRECATED: The cname() method has been renamed to getname().     The
#     preferred method of obtaining a component name is to use the     .name
#     property, which returns the fully qualified component name.     The
#     .local_name property will return the component name only within the
#     context of the immediate parent container.  (deprecated in 5.0) (called
#     from d:\Anaconda3\envs\Optimization\lib\site-
#     packages\IPython\core\interactiveshell.py:3378)
# x[G0,Tue,M1i] 1.0
# x[G0,Wed,E2n] 1.0
# x[G0,Thu,E1n] 1.0
# x[G0,Fri,M3i] 1.0
# x[G1,Mon,M1n] 1.0
# x[G1,Wed,M1i] 1.0
# x[G1,Thu,E2n] 1.0
# x[G1,Fri,M1i] 1.0
# x[G2,Mon,E2n] 1.0
# x[G2,Tue,M1n] 1.0
# x[G2,Fri,M3n] 1.0
# x[G2,Sat,M2i] 1.0
# x[G3,Tue,E1n] 1.0
# x[G3,Wed,M2i] 1.0
# x[G3,Thu,M2i] 1.0
# x[G3,Fri,E1n] 1.0
# x[G4,Tue,M3i] 1.0
# x[G4,Wed,E3n] 1.0
# x[G4,Thu,M2i] 1.0
# x[G4,Sat,M3i] 1.0
# x[G5,Wed,E1n] 1.0
# x[G5,Thu,M1i] 1.0
# x[G5,Fri,M2n] 1.0
# x[G5,Sun,E3n] 1.0
# x[G6,Mon,M2i] 1.0
# x[G6,Tue,M1i] 1.0
# x[G6,Thu,E2i] 1.0
# x[G6,Fri,M2i] 1.0
# x[G7,Mon,M1n] 1.0
# x[G7,Wed,E1i] 1.0
# x[G7,Thu,E1i] 1.0
# x[G7,Fri,E1i] 1.0
# x[G8,Mon,E1i] 1.0
# x[G8,Wed,E2i] 1.0
# x[G8,Thu,M1i] 1.0
# x[G8,Sun,M2i] 1.0
# x[G9,Mon,E3i] 1.0
# x[G9,Fri,E2i] 1.0
# x[G9,Sat,E3i] 1.0
# x[G9,Sun,E3i] 1.0
# x[G10,Mon,E2i] 1.0
# x[G10,Tue,M3n] 1.0
# x[G10,Fri,E2n] 1.0
# x[G10,Sun,M3i] 1.0
# x[G11,Mon,E3n] 1.0
# x[G11,Wed,E1i] 1.0
# x[G11,Thu,M3n] 1.0
# x[G11,Sat,M2n] 1.0
# x[G12,Tue,M2i] 1.0
# x[G12,Wed,M1n] 1.0
# x[G12,Thu,E1i] 1.0
# x[G12,Fri,E1i] 1.0
# x[G13,Mon,E1n] 1.0
# x[G13,Tue,E2n] 1.0
# x[G13,Wed,M2n] 1.0
# x[G13,Fri,E2i] 1.0
# x[G14,Mon,M2n] 1.0
# x[G14,Tue,E3i] 1.0
# x[G14,Wed,M3i] 1.0
# x[G14,Thu,E3n] 1.0
# x[G15,Mon,E1i] 1.0
# x[G15,Tue,E1i] 1.0
# x[G15,Thu,M2n] 1.0
# x[G15,Sun,M2n] 1.0
# x[G16,Mon,M2i] 1.0
# x[G16,Tue,E3n] 1.0
# x[G16,Thu,M3i] 1.0
# x[G16,Fri,E3i] 1.0
# x[G17,Mon,M3i] 1.0
# x[G17,Thu,E2i] 1.0
# x[G17,Fri,M1i] 1.0
# x[G17,Sun,M3n] 1.0
# x[G18,Tue,E2i] 1.0
# x[G18,Wed,M1i] 1.0
# x[G18,Thu,E3i] 1.0
# x[G18,Sat,E3n] 1.0
# x[G19,Mon,M1i] 1.0
# x[G19,Tue,E2i] 1.0
# x[G19,Fri,M2i] 1.0
# x[G19,Sat,M2i] 1.0
# x[G20,Mon,M3n] 1.0
# x[G20,Wed,M2i] 1.0
# x[G20,Fri,M1n] 1.0
# x[G20,Sun,M2i] 1.0
# x[G21,Mon,E2i] 1.0
# x[G21,Tue,M2n] 1.0
# x[G21,Wed,M3n] 1.0
# x[G21,Fri,E3n] 1.0
# x[G22,Mon,M1i] 1.0
# x[G22,Wed,E3i] 1.0
# x[G22,Thu,M1n] 1.0
# x[G22,Sat,M3n] 1.0
# x[G23,Tue,E1i] 1.0
# x[G23,Fri,M1i] 1.0
# x[G23,Sat,M2i] 1.0
# x[G23,Sun,M2i] 1.0

# %% [markdown]
# ### 9. Bibliography
#
# [<a id="jcyl-icu-beds">1</a>] “Ocupación de camas en hospitales” 2022. [Online]. Available: https://analisis.datosabiertos.jcyl.es/explore/dataset/ocupacion-de-camas-en-hospitales/information/?sort=camas_habilitadas_uci&dataChart=...%3D%3D&refine.fecha=2021&refine.hospital=Complejo+Asistencial+Universitario+de+Le%C3%B3n. [Updated: 07-Oct-2022, 12:54 PM; Accessed: 09-Oct-2022]
#
# [<a id="jcyl-icu-profile">2</a>] “Información General Medicina Intensiva del Complejo Asistencial Universitario de León,” 05-May-2022. [Online]. Available: https://www.saludcastillayleon.es/CHLeon/es/carteraservicios/servicios-centrales/medicina-intensiva. [Updated: 05-May-2022; Accessed: 09-Oct-2022]
#
# [<a id="icu-levels">3</a>] V. Gómez Tello *et al.*, “Estimación de las necesidades de profesionales médicos en los servicios de medicina intensiva,” vol. 42, no. 1, pp. 37–46, 2018, doi: https://doi.org/10.1016/j.medin.2017.09.013. [Online]. Available: https://www.sciencedirect.com/science/article/pii/S0210569117302851 [Accessed: 09-Oct-2022]
#
# [<a id="optimal-PIR">4</a>] H. B. Gershengorn, D. A. Harrison, A. Garland, M. E. Wilcox, K. M. Rowan, and H. Wunsch, “Association of Intensive Care Unit Patient-to-Intensivist Ratios With Hospital Mortality,” vol. 177, no. 3, pp. 388–396, 2017, doi: 10.1001/jamainternmed.2016.8457. [Online]. Available: https://doi.org/10.1001/jamainternmed.2016.8457 [Accessed: 09-Oct-2022]
#
# [<a id="cone-dual">5</a>] Gordon G., "Linear Programming, Lagrange Multipliers, and Duality". School of Computer Science, Carnegie Mellon University. [Online]. Available: http://www.cs.cmu.edu/~ggordon/lp.pdf [Accessed: 29-Oct-2022]
#
# [<a id="2003/88/CE">6</a>] Directive 2003/88/EC of the European Parliament and of the Council of 4 November 2003 concerning certain aspects of the organisation of working time. Official Journal L 299 , 18/11/2003 P. 0009 - 0019. [Online]. Available: https://eur-lex.europa.eu/legal-content/EN/TXT/HTML/?uri=CELEX:32003L0088&from=EN [Accessed: 30-Oct-2022]
